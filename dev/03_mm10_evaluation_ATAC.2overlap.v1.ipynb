# %%
#-----import packages-----#

#common python packages
import numpy as np
import string
import random
import os
import pickle
import argparse
import wget
import math
import gc
import matplotlib.pyplot as plt
from datetime import datetime
from tempfile import TemporaryFile

#biological packages
import pybedtools
from pybedtools import featurefuncs
import pyBigWig

#machine learning packages
import sklearn
from sklearn import metrics
from sklearn.utils import shuffle, class_weight
from matplotlib import pyplot as plt
import pandas as pd

import tensorflow as tf

import keras.backend as K
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Conv2D, MaxPooling2D, BatchNormalization, Flatten, GlobalAveragePooling2D, Multiply
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from keras import backend as K
from keras.engine.topology import Layer, InputSpec
from keras.utils import Sequence, plot_model
from keras.constraints import unit_norm
from keras import regularizers
from keras.callbacks import EarlyStopping, Callback, TensorBoard, ReduceLROnPlateau
import keras_metrics as km
from keras.models import load_model

from models.v1 import create_model
from models.custom_metrics import auroc, auprc, recall_m, precision_m, f1_m

#notify the OS about GPU
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['KERAS_BACKEND'] = 'tensorflow'
# Out:
# Using TensorFlow backend.

# %%
#parsing command line arguments
# -----parsing command line arguments-----#
parser = argparse.ArgumentParser(description='Training CNN model to predict STARR-seq enhancers based on chromatin accessbility and histone marks')
parser.add_argument('-c', '--cell_types', type=str, help='comma separated string of cell_types')
parser.add_argument('-i', '--in_dir', type=str, help='directory containing 01_data_encoding intermediate tsv files')

#simulate command line input
cmdline_str='-c ' + " HepG2,K562 " + \
    ' -i ' + "/gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/dev/encoded_2overlap/ATAC/"

seq_names = ["ATAC", "H3K27ac", "H3K4me3", "H3K9ac", "H3K4me1"]

#check if the files are there
args = parser.parse_args(cmdline_str.split())
args.cell_types = args.cell_types.split(",")
for cell in args.cell_types:
    for seq in seq_names:
        pos_file = args.in_dir + cell + "." + seq + ".pos.tsv"
        if not os.path.exists(pos_file):
            print(pos_file + " file does not exist")
            exit(1)
        neg_file = args.in_dir + cell + "." + seq + ".neg.tsv"
        if not os.path.exists(neg_file):
            print(neg_file + " file does not exist")
            exit(1)
print("all files found!")
# Out:
# all files found!

# %%
def get_data(cell_types, in_dir, seq_names):

    first_cell = True
    for cell in cell_types:
        print(cell)

        pos = []
        neg = []
        first_seq = True
        for seq in seq_names:
            print("-"+seq)

            pos_name = in_dir+cell+"."+seq+".pos.tsv"
            pos_mat = np.loadtxt(pos_name, delimiter='\t')

            neg_name = in_dir+cell+"."+seq+".neg.tsv"
            neg_mat = np.loadtxt(neg_name, delimiter='\t')

            if first_seq:
                for i in pos_mat:
                    pos.append(np.array([i]))
                for i in neg_mat:
                    neg.append(np.array([i]))
                first_seq = False
            else:
                for i in range(len(pos)):
                    pos[i] = np.vstack((pos[i], pos_mat[i,]))
                for i in range(len(neg)):
                    neg[i] = np.vstack((neg[i], neg_mat[i,]))

        if first_cell == True:
            X_pos = np.array(pos)
            X_neg = np.array(neg)
            first_cell = False
        else:
            X_pos = np.vstack((X_pos, pos))
            X_neg = np.vstack((X_neg, neg))

    X = np.vstack((X_pos, X_neg))
    y = np.array([1 for i in range(X_pos.shape[0])] + [0 for i in range(X_neg.shape[0])]).reshape(-1,1)
    print(X.shape)
    print(y.shape)
    
    return X, y
  
# X, y = get_data(args.cell_types, args.in_dir, seq_names)
# with open(args.in_dir + "hg38_signals.pickle", 'wb') as f:
#     pickle.dump((X,y), f)

# %%
with open(args.in_dir + "hg38_signals.pickle", 'rb') as f:
    X, y = pickle.load(f)
window_size = int(X.shape[2] * 10)
X, y = shuffle(X, y, random_state=0)
x_train = np.expand_dims(X, axis=4)
y_train = y

#calculate class weights
class_weights = class_weight.compute_class_weight('balanced',
                                                  np.unique(y_train),
                                                  y_train.flatten())
# Out:
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   """

# %%
es = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)

# construct the model
model = create_model(width=int(window_size/10))

adam = Adam(lr=5e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=9e-5)
model.compile(loss='binary_crossentropy', optimizer=adam, 
    metrics=['accuracy', auroc, auprc, f1_m, recall_m, precision_m])

#train the model
history = model.fit(x_train, y_train,
                    batch_size=32,
                    epochs=100,
                    validation_split=0.1,
                    shuffle=True,
                    class_weight=class_weights,
                    callbacks=[es]) 

model.save_weights('./saved_models/ATAC_hg38.v1.h5')
# Out:
# /gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/dev/models/v1.py:59: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   model = Model(input=[input_size], output=[pred_output])
# Train on 142332 samples, validate on 15815 samples
# Epoch 1/100
# 142332/142332 [==============================] - 132s 930us/step - loss: 0.1644 - acc: 0.9762 - auroc: 0.9468 - auprc: 0.7776 - f1_m: 0.8026 - recall_m: 0.8440 - precision_m: 0.7948 - val_loss: 0.0870 - val_acc: 0.9844 - val_auroc: 0.9911 - val_auprc: 0.9121 - val_f1_m: 0.8876 - val_recall_m: 0.9564 - val_precision_m: 0.8473
# Epoch 2/100
# 142332/142332 [==============================] - 128s 900us/step - loss: 0.0742 - acc: 0.9868 - auroc: 0.9933 - auprc: 0.9292 - f1_m: 0.8795 - recall_m: 0.9168 - precision_m: 0.8651 - val_loss: 0.0648 - val_acc: 0.9875 - val_auroc: 0.9946 - val_auprc: 0.9392 - val_f1_m: 0.9050 - val_recall_m: 0.9560 - val_precision_m: 0.8754
# Epoch 3/100
# 142332/142332 [==============================] - 128s 899us/step - loss: 0.0612 - acc: 0.9885 - auroc: 0.9952 - auprc: 0.9448 - f1_m: 0.8879 - recall_m: 0.9229 - precision_m: 0.8736 - val_loss: 0.0568 - val_acc: 0.9891 - val_auroc: 0.9956 - val_auprc: 0.9487 - val_f1_m: 0.9111 - val_recall_m: 0.9322 - val_precision_m: 0.9066
# Epoch 4/100
# 142332/142332 [==============================] - 128s 900us/step - loss: 0.0545 - acc: 0.9891 - auroc: 0.9959 - auprc: 0.9516 - f1_m: 0.8963 - recall_m: 0.9289 - precision_m: 0.8834 - val_loss: 0.0558 - val_acc: 0.9876 - val_auroc: 0.9962 - val_auprc: 0.9539 - val_f1_m: 0.9064 - val_recall_m: 0.9562 - val_precision_m: 0.8773
# Epoch 5/100
# 142332/142332 [==============================] - 128s 899us/step - loss: 0.0505 - acc: 0.9895 - auroc: 0.9963 - auprc: 0.9556 - f1_m: 0.8924 - recall_m: 0.9252 - precision_m: 0.8785 - val_loss: 0.0487 - val_acc: 0.9904 - val_auroc: 0.9965 - val_auprc: 0.9572 - val_f1_m: 0.9209 - val_recall_m: 0.9558 - val_precision_m: 0.9009
# Epoch 6/100
# 142332/142332 [==============================] - 128s 899us/step - loss: 0.0473 - acc: 0.9896 - auroc: 0.9966 - auprc: 0.9587 - f1_m: 0.8953 - recall_m: 0.9266 - precision_m: 0.8822 - val_loss: 0.0457 - val_acc: 0.9898 - val_auroc: 0.9967 - val_auprc: 0.9597 - val_f1_m: 0.9175 - val_recall_m: 0.9536 - val_precision_m: 0.8968
# Epoch 7/100
# 142332/142332 [==============================] - 128s 899us/step - loss: 0.0452 - acc: 0.9900 - auroc: 0.9968 - auprc: 0.9607 - f1_m: 0.8976 - recall_m: 0.9287 - precision_m: 0.8840 - val_loss: 0.0448 - val_acc: 0.9904 - val_auroc: 0.9969 - val_auprc: 0.9615 - val_f1_m: 0.9185 - val_recall_m: 0.9439 - val_precision_m: 0.9069
# Epoch 8/100
# 142332/142332 [==============================] - 128s 899us/step - loss: 0.0433 - acc: 0.9904 - auroc: 0.9970 - auprc: 0.9625 - f1_m: 0.8963 - recall_m: 0.9272 - precision_m: 0.8824 - val_loss: 0.0426 - val_acc: 0.9902 - val_auroc: 0.9971 - val_auprc: 0.9632 - val_f1_m: 0.9179 - val_recall_m: 0.9402 - val_precision_m: 0.9099
# Epoch 9/100
# 142332/142332 [==============================] - 128s 899us/step - loss: 0.0420 - acc: 0.9905 - auroc: 0.9971 - auprc: 0.9639 - f1_m: 0.8981 - recall_m: 0.9251 - precision_m: 0.8868 - val_loss: 0.0413 - val_acc: 0.9905 - val_auroc: 0.9972 - val_auprc: 0.9644 - val_f1_m: 0.9210 - val_recall_m: 0.9476 - val_precision_m: 0.9085
# Epoch 10/100
# 142332/142332 [==============================] - 128s 900us/step - loss: 0.0406 - acc: 0.9907 - auroc: 0.9972 - auprc: 0.9651 - f1_m: 0.9015 - recall_m: 0.9293 - precision_m: 0.8905 - val_loss: 0.0407 - val_acc: 0.9903 - val_auroc: 0.9973 - val_auprc: 0.9656 - val_f1_m: 0.9185 - val_recall_m: 0.9500 - val_precision_m: 0.9019
# Epoch 11/100
# 142332/142332 [==============================] - 128s 900us/step - loss: 0.0395 - acc: 0.9907 - auroc: 0.9973 - auprc: 0.9662 - f1_m: 0.9013 - recall_m: 0.9299 - precision_m: 0.8885 - val_loss: 0.0421 - val_acc: 0.9899 - val_auroc: 0.9974 - val_auprc: 0.9667 - val_f1_m: 0.9188 - val_recall_m: 0.9570 - val_precision_m: 0.8971
# Epoch 12/100
# 142332/142332 [==============================] - 128s 901us/step - loss: 0.0388 - acc: 0.9910 - auroc: 0.9974 - auprc: 0.9671 - f1_m: 0.9048 - recall_m: 0.9328 - precision_m: 0.8925 - val_loss: 0.0396 - val_acc: 0.9906 - val_auroc: 0.9975 - val_auprc: 0.9675 - val_f1_m: 0.9219 - val_recall_m: 0.9528 - val_precision_m: 0.9055
# Epoch 13/100
# 142332/142332 [==============================] - 128s 901us/step - loss: 0.0379 - acc: 0.9909 - auroc: 0.9975 - auprc: 0.9680 - f1_m: 0.9004 - recall_m: 0.9277 - precision_m: 0.8891 - val_loss: 0.0395 - val_acc: 0.9903 - val_auroc: 0.9975 - val_auprc: 0.9683 - val_f1_m: 0.9202 - val_recall_m: 0.9552 - val_precision_m: 0.9011
# Epoch 14/100
# 142332/142332 [==============================] - 128s 900us/step - loss: 0.0370 - acc: 0.9912 - auroc: 0.9976 - auprc: 0.9687 - f1_m: 0.9063 - recall_m: 0.9341 - precision_m: 0.8949 - val_loss: 0.0380 - val_acc: 0.9911 - val_auroc: 0.9976 - val_auprc: 0.9690 - val_f1_m: 0.9241 - val_recall_m: 0.9498 - val_precision_m: 0.9118
# Epoch 15/100
# 142332/142332 [==============================] - 128s 900us/step - loss: 0.0368 - acc: 0.9912 - auroc: 0.9976 - auprc: 0.9694 - f1_m: 0.9041 - recall_m: 0.9300 - precision_m: 0.8928 - val_loss: 0.0373 - val_acc: 0.9908 - val_auroc: 0.9976 - val_auprc: 0.9696 - val_f1_m: 0.9204 - val_recall_m: 0.9387 - val_precision_m: 0.9154
# Epoch 16/100
# 142332/142332 [==============================] - 128s 901us/step - loss: 0.0363 - acc: 0.9914 - auroc: 0.9977 - auprc: 0.9699 - f1_m: 0.9083 - recall_m: 0.9349 - precision_m: 0.8974 - val_loss: 0.0372 - val_acc: 0.9907 - val_auroc: 0.9977 - val_auprc: 0.9701 - val_f1_m: 0.9196 - val_recall_m: 0.9377 - val_precision_m: 0.9154
# Epoch 17/100
# 142332/142332 [==============================] - 128s 901us/step - loss: 0.0356 - acc: 0.9915 - auroc: 0.9977 - auprc: 0.9705 - f1_m: 0.9017 - recall_m: 0.9270 - precision_m: 0.8912 - val_loss: 0.0362 - val_acc: 0.9912 - val_auroc: 0.9977 - val_auprc: 0.9707 - val_f1_m: 0.9254 - val_recall_m: 0.9566 - val_precision_m: 0.9076
# Epoch 18/100
# 142332/142332 [==============================] - 128s 901us/step - loss: 0.0353 - acc: 0.9916 - auroc: 0.9977 - auprc: 0.9710 - f1_m: 0.9048 - recall_m: 0.9304 - precision_m: 0.8940 - val_loss: 0.0372 - val_acc: 0.9910 - val_auroc: 0.9978 - val_auprc: 0.9712 - val_f1_m: 0.9221 - val_recall_m: 0.9389 - val_precision_m: 0.9196
# Epoch 19/100
# 142332/142332 [==============================] - 128s 902us/step - loss: 0.0349 - acc: 0.9915 - auroc: 0.9978 - auprc: 0.9714 - f1_m: 0.9016 - recall_m: 0.9272 - precision_m: 0.8911 - val_loss: 0.0358 - val_acc: 0.9912 - val_auroc: 0.9978 - val_auprc: 0.9716 - val_f1_m: 0.9220 - val_recall_m: 0.9470 - val_precision_m: 0.9106
# Epoch 20/100
# 142332/142332 [==============================] - 128s 901us/step - loss: 0.0346 - acc: 0.9917 - auroc: 0.9978 - auprc: 0.9718 - f1_m: 0.9079 - recall_m: 0.9344 - precision_m: 0.8975 - val_loss: 0.0363 - val_acc: 0.9913 - val_auroc: 0.9978 - val_auprc: 0.9720 - val_f1_m: 0.9244 - val_recall_m: 0.9408 - val_precision_m: 0.9224
# Epoch 21/100
# 142332/142332 [==============================] - 128s 901us/step - loss: 0.0342 - acc: 0.9917 - auroc: 0.9978 - auprc: 0.9722 - f1_m: 0.9050 - recall_m: 0.9314 - precision_m: 0.8934 - val_loss: 0.0349 - val_acc: 0.9915 - val_auroc: 0.9979 - val_auprc: 0.9723 - val_f1_m: 0.9251 - val_recall_m: 0.9492 - val_precision_m: 0.9139
# Epoch 22/100
# 142332/142332 [==============================] - 128s 900us/step - loss: 0.0340 - acc: 0.9918 - auroc: 0.9979 - auprc: 0.9725 - f1_m: 0.9057 - recall_m: 0.9298 - precision_m: 0.8959 - val_loss: 0.0346 - val_acc: 0.9917 - val_auroc: 0.9979 - val_auprc: 0.9727 - val_f1_m: 0.9266 - val_recall_m: 0.9561 - val_precision_m: 0.9101
# Epoch 23/100
# 142332/142332 [==============================] - 128s 899us/step - loss: 0.0338 - acc: 0.9919 - auroc: 0.9979 - auprc: 0.9728 - f1_m: 0.9071 - recall_m: 0.9319 - precision_m: 0.8966 - val_loss: 0.0345 - val_acc: 0.9913 - val_auroc: 0.9979 - val_auprc: 0.9729 - val_f1_m: 0.9227 - val_recall_m: 0.9471 - val_precision_m: 0.9113
# Epoch 24/100
# 142332/142332 [==============================] - 128s 899us/step - loss: 0.0333 - acc: 0.9919 - auroc: 0.9979 - auprc: 0.9731 - f1_m: 0.9124 - recall_m: 0.9371 - precision_m: 0.9020 - val_loss: 0.0343 - val_acc: 0.9918 - val_auroc: 0.9979 - val_auprc: 0.9732 - val_f1_m: 0.9294 - val_recall_m: 0.9567 - val_precision_m: 0.9145
# Epoch 25/100
# 142332/142332 [==============================] - 128s 898us/step - loss: 0.0333 - acc: 0.9919 - auroc: 0.9979 - auprc: 0.9734 - f1_m: 0.9073 - recall_m: 0.9319 - precision_m: 0.8970 - val_loss: 0.0342 - val_acc: 0.9915 - val_auroc: 0.9980 - val_auprc: 0.9735 - val_f1_m: 0.9260 - val_recall_m: 0.9478 - val_precision_m: 0.9179
# Epoch 26/100
# 142332/142332 [==============================] - 128s 898us/step - loss: 0.0332 - acc: 0.9918 - auroc: 0.9980 - auprc: 0.9736 - f1_m: 0.9059 - recall_m: 0.9309 - precision_m: 0.8957 - val_loss: 0.0344 - val_acc: 0.9915 - val_auroc: 0.9980 - val_auprc: 0.9737 - val_f1_m: 0.9268 - val_recall_m: 0.9585 - val_precision_m: 0.9087
# Epoch 27/100
# 142332/142332 [==============================] - 128s 899us/step - loss: 0.0327 - acc: 0.9918 - auroc: 0.9980 - auprc: 0.9739 - f1_m: 0.9014 - recall_m: 0.9264 - precision_m: 0.8906 - val_loss: 0.0354 - val_acc: 0.9911 - val_auroc: 0.9980 - val_auprc: 0.9740 - val_f1_m: 0.9231 - val_recall_m: 0.9392 - val_precision_m: 0.9217

# %%
# --- ENCODE mm10 validation #1 ---#
def rename_tissue(feature):
    feature.name = feature[9]
    return feature

val_file1 = "/gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/datasets/validation/ENCFF095OCG.bed"
val_region1 = pybedtools.BedTool(val_file1).each(pybedtools.featurefuncs.midpoint).each(rename_tissue)
val_region1 = val_region1.slop(b=window_size/2, genome="mm10")
val_region1 = val_region1.filter(pybedtools.featurefuncs.greater_than, window_size-1)
val_region1 = val_region1.sort()
val_region1.head()
# Out:
# chr1	13003151	13007152	negative	0	.	13003747	13006556	0,0,255	negative
#  chr1	31101021	31105022	negative	0	.	31101599	31104444	0,0,255	negative
#  chr1	38197302	38201303	negative	0	.	38196744	38201861	0,0,255	negative
#  chr1	39946111	39950112	forebrain [7/9], cranial nerve [7/9], dorsal root ganglion [7/9]	1	.	39945533	39950689	255,0,0	forebrain [7/9], cranial nerve [7/9], dorsal root ganglion [7/9]
#  chr1	68778680	68782681	negative	0	.	68779329	68782031	0,0,255	negative
#  chr1	75287729	75291730	forebrain [5/12]	1	.	75288287	75291172	255,0,0	forebrain [5/12]
#  chr1	75405463	75409464	negative	0	.	75405116	75409810	0,0,255	negative
#  chr1	97538619	97542620	forebrain [3/4], midbrain [3/4], hindbrain [3/4], neural tube [3/4]	1	.	97538497	97542741	255,0,0	forebrain [3/4], midbrain [3/4], hindbrain [3/4], neural tube [3/4]
#  chr1	127754934	127758935	negative	0	.	127754802	127759066	0,0,255	negative
#  chr1	158264756	158268757	midbrain [3/4], hindbrain [3/4], neck [3/4]	1	.	158265467	158268046	255,0,0	midbrain [3/4], hindbrain [3/4], neck [3/4]

# %%
# --- ENCODE mm10 validation #2 --- #
# val_file2 = "/gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/datasets/validation/ENCFF915YMM.bed"
# val_region2 = pybedtools.BedTool(val_file2).each(pybedtools.featurefuncs.midpoint).each(rename_tissue)
# val_region2 = val_region2.slop(b=window_size/2, genome="mm10")
# val_region2 = val_region2.filter(pybedtools.featurefuncs.greater_than, window_size-1)
# val_region2 = val_region2.sort()
# val_region2.head()

# %%
# --- VISTA mm9->mm10 validation ---#

val_file3_raw = "/gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/datasets/validation/VISTA_mm10_raw.bed"
val_file3_label = "/gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/datasets/validation/VISTA_mm9.txt"
val_file3 = "/gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/datasets/validation/VISTA_mm10.bed"

df1 = pd.read_csv(val_file3_raw, sep="\t",header=None)
df1_label = pd.read_csv(val_file3_label, sep="\t",header=None)
df1[3] = df1_label[3]
df1.to_csv(val_file3, sep="\t",header=None, index=False)

val_region3 = pybedtools.BedTool(val_file3)
val_region3 = val_region3.each(pybedtools.featurefuncs.midpoint)
val_region3 = val_region3.slop(b=window_size/2, genome="mm10")
val_region3 = val_region3.filter(pybedtools.featurefuncs.greater_than, window_size-1)
val_region3 = val_region3.sort()
val_region3.head()
# print("limb" in val_region3[3][3])
# Out:
# chr1	5020950	5024951	element 911 | negative
#  chr1	9647594	9651595	element 1545 | negative
#  chr1	11025292	11029293	element 659 | negative
#  chr1	12498493	12502494	element 1417 | positive  | limb[5/5] | tail[5/5]
#  chr1	12508534	12512535	element 1415 | positive  | limb[9/9]
#  chr1	12614067	12618068	element 663 | negative
#  chr1	13003151	13007152	element 1341 | positive  | hindbrain (rhombencephalon)[6/6] | midbrain (mesencephalon)[6/6] | forebrain[6/6] | limb[6/6] | other[3/6]
#  chr1	19765625	19769626	element 1771 | negative
#  chr1	31101021	31105022	element 1356 | negative
#  chr1	33988988	33992989	element 664 | negative

# %%
# --- merge validation regions from all three sources --- #
# validation_regions = val_region1.cat(val_region2, postmerge=False).cat(val_region3, postmerge=False)
validation_regions = val_region1.cat(val_region3, postmerge=False)
validation_regions.saveas("./mm10/mm10.validation_regions.bed")
# validation_regions.head()
# Out:
# <BedTool(./mm10/mm10.validation_regions.bed)>

# %%
# ---- separate positive and negative for each tissue from the files ---- #

def tissue_pos(feature, tissue):
    if tissue in feature.name:
        return True
    else:
        return False

def tissue_neg(feature, tissue):
    if tissue in feature.name:
        return False
    else:
        return True
    
samples = ["forebrain", "heart", "hindbrain", "limb", "midbrain", "neural tube"]
seq_names = ["ATAC-seq", "ChIP-seq.H3K27ac", "ChIP-seq.H3K4me3", "ChIP-seq.H3K9ac", "ChIP-seq.H3K4me1"]
sample_dir = "/gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/datasets/validation/bigWig/"

# %%
# # ---- read in bigwig files ---- #
# def bigWigAverageOverBed(x, bigwig):
# #     print(x)
#     return bigwig.stats(x.chrom, x.start, x.stop, nBins=int(window_size/10))

# def get_signal(region, bigwig):
#     return [bigWigAverageOverBed(x, bigwig) for x in region]

# file_samples = ["forebrain", "heart", "hindbrain", "limb", "midbrain", "neural_tube"]

# peak_set = []
# track_set = []
# for sam in file_samples:
#     all_seq_peak = []
#     all_seq_track = []
#     for seq in seq_names:
#         all_seq_peak.append(sample_dir + sam + "."+ seq + ".narrowPeak")
#         all_seq_track.append(sample_dir + sam + "."+ seq + ".bigWig")
#     peak_set.append(all_seq_peak)
#     track_set.append(all_seq_track)


# # print(track_set)

# X = []
# Y = []
# for i in range(len(samples)):
    
#     #organized per track for all samples
#     signal_X = []
#     signal_Y = []
#     for track in track_set[i]:
#     #   print(track)        
#         pos_bed = pybedtools.BedTool("./mm10/mm10.validation_regions.bed").filter(tissue_pos, samples[i])
#         neg_bed = pybedtools.BedTool("./mm10/mm10.validation_regions.bed").filter(tissue_neg, samples[i])
#         pos = get_signal(pos_bed, pyBigWig.open(track))
#         neg = get_signal(neg_bed, pyBigWig.open(track))

#         x_combined = pos + neg
#         signal_X.append(x_combined)
        
#     print(samples[i], len(pos), len(neg))
        
#     #reorganize per sample for all tracks
#     signal_reform_X = []
#     for j in range(len(x_combined)):
#         per_track_X = []
#         for t in range(len(track_set[i])):
#             per_track_X.append(np.array(signal_X[t][j]))
#         signal_reform_X.append(np.array(per_track_X))
#     signal_reform_X = np.expand_dims(np.array(signal_reform_X), axis=4)
#     X.append(signal_reform_X)
    
#     y_combined = [1 for i in pos] + [0 for i in neg]
#     Y.append(np.array(y_combined))
    
# with open(args.in_dir + "mm10_signals.pickle", 'wb') as f:
#     pickle.dump((X,Y), f)

# %%
with open("./mm10/mm10_signals.pickle", 'rb') as f:
    X,Y = pickle.load(f)

# %%
y_pred_list = []
accuracy_list = []
for i in range(len(samples)):
    y_pred = model.predict(X[i]).ravel()
    y_pred_list.append(y_pred)

    accuracy_s = sklearn.metrics.accuracy_score(Y[i], np.rint(y_pred))
    print(samples[i], "validation accuracy is:", accuracy_s)
    accuracy_list.append(accuracy_s)
# Out:
# forebrain validation accuracy is: 0.6723989681857265
# heart validation accuracy is: 0.709372312983663
# hindbrain validation accuracy is: 0.6981943250214961
# limb validation accuracy is: 0.6835769561478934
# midbrain validation accuracy is: 0.6638005159071367
# neural tube validation accuracy is: 0.705073086844368

# %%
y_pred_list = []
accuracy_list = []
for i in range(len(samples)):
    
    #fine-tuning
    X_ft = X.copy()
    X_ft.pop(i)
    X_ft = np.array(X_ft)
    X_ft = X_ft.reshape((-1, X_ft.shape[2], X_ft.shape[3], X_ft.shape[4]))
    
    Y_ft = Y.copy()
    Y_ft.pop(i)
    Y_ft = np.array(Y_ft)
    Y_ft = Y_ft.reshape((-1, 1))
    
    X_ft, Y_ft = shuffle(X_ft, Y_ft, random_state=0)
    
    class_weights = class_weight.compute_class_weight('balanced',
                                                  np.unique(Y_ft),
                                                  Y_ft.flatten())
    
    es = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
    
    ft_model = create_model(width=int(window_size/10))
    ft_model.load_weights('./saved_models/ATAC_hg38.v1.h5')
    ft_model.compile(loss='binary_crossentropy', 
                     optimizer=Adam(lr=1e-6, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=9e-5), 
                     metrics=['accuracy', auroc, auprc, f1_m, recall_m, precision_m])
    
    #train the model
    history = ft_model.fit(X_ft, Y_ft,
                        batch_size=4,
                        epochs=100,
                        validation_split=0.1,
                        shuffle=True,
                        class_weight=class_weights,
                        callbacks=[es])
    
    

    y_pred = ft_model.predict(X[i]).ravel()
    y_pred_list.append(y_pred)

    accuracy_s = sklearn.metrics.accuracy_score(Y[i], np.rint(y_pred))
    print(samples[i], "validation accuracy is:", accuracy_s)
    accuracy_list.append(accuracy_s)
# Out:
# /gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/dev/models/v1.py:59: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   model = Model(input=[input_size], output=[pred_output])
# Train on 5233 samples, validate on 582 samples
# Epoch 1/100
# 5233/5233 [==============================] - 24s 4ms/step - loss: 0.6769 - acc: 0.7737 - auroc: 0.6806 - auprc: 0.2259 - f1_m: 0.1305 - recall_m: 0.1455 - precision_m: 0.1323 - val_loss: 0.5439 - val_acc: 0.8711 - val_auroc: 0.6620 - val_auprc: 0.2210 - val_f1_m: 0.0412 - val_recall_m: 0.0412 - val_precision_m: 0.0412
# Epoch 2/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4637 - acc: 0.8588 - auroc: 0.6618 - auprc: 0.2203 - f1_m: 0.0204 - recall_m: 0.0199 - precision_m: 0.0218 - val_loss: 0.4812 - val_acc: 0.8711 - val_auroc: 0.6574 - val_auprc: 0.2168 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 3/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4381 - acc: 0.8601 - auroc: 0.6544 - auprc: 0.2136 - f1_m: 0.0036 - recall_m: 0.0032 - precision_m: 0.0046 - val_loss: 0.4558 - val_acc: 0.8729 - val_auroc: 0.6515 - val_auprc: 0.2122 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 4/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4325 - acc: 0.8603 - auroc: 0.6506 - auprc: 0.2125 - f1_m: 0.0054 - recall_m: 0.0050 - precision_m: 0.0061 - val_loss: 0.4397 - val_acc: 0.8729 - val_auroc: 0.6481 - val_auprc: 0.2107 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 5/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4185 - acc: 0.8613 - auroc: 0.6481 - auprc: 0.2105 - f1_m: 0.0041 - recall_m: 0.0038 - precision_m: 0.0046 - val_loss: 0.4300 - val_acc: 0.8729 - val_auroc: 0.6474 - val_auprc: 0.2106 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 6/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4153 - acc: 0.8615 - auroc: 0.6475 - auprc: 0.2112 - f1_m: 0.0066 - recall_m: 0.0065 - precision_m: 0.0069 - val_loss: 0.4233 - val_acc: 0.8729 - val_auroc: 0.6471 - val_auprc: 0.2116 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 7/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4092 - acc: 0.8634 - auroc: 0.6477 - auprc: 0.2125 - f1_m: 0.0103 - recall_m: 0.0096 - precision_m: 0.0122 - val_loss: 0.4180 - val_acc: 0.8729 - val_auroc: 0.6475 - val_auprc: 0.2130 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 8/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4073 - acc: 0.8615 - auroc: 0.6482 - auprc: 0.2140 - f1_m: 0.0062 - recall_m: 0.0056 - precision_m: 0.0076 - val_loss: 0.4142 - val_acc: 0.8746 - val_auroc: 0.6479 - val_auprc: 0.2144 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 9/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4068 - acc: 0.8611 - auroc: 0.6480 - auprc: 0.2150 - f1_m: 0.0079 - recall_m: 0.0073 - precision_m: 0.0092 - val_loss: 0.4112 - val_acc: 0.8746 - val_auroc: 0.6479 - val_auprc: 0.2157 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 10/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4045 - acc: 0.8615 - auroc: 0.6482 - auprc: 0.2163 - f1_m: 0.0080 - recall_m: 0.0071 - precision_m: 0.0099 - val_loss: 0.4086 - val_acc: 0.8746 - val_auroc: 0.6485 - val_auprc: 0.2170 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 11/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4000 - acc: 0.8632 - auroc: 0.6493 - auprc: 0.2177 - f1_m: 0.0113 - recall_m: 0.0102 - precision_m: 0.0138 - val_loss: 0.4063 - val_acc: 0.8746 - val_auroc: 0.6498 - val_auprc: 0.2187 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 12/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4044 - acc: 0.8609 - auroc: 0.6502 - auprc: 0.2195 - f1_m: 0.0096 - recall_m: 0.0087 - precision_m: 0.0115 - val_loss: 0.4043 - val_acc: 0.8746 - val_auroc: 0.6506 - val_auprc: 0.2203 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 13/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3985 - acc: 0.8607 - auroc: 0.6511 - auprc: 0.2210 - f1_m: 0.0064 - recall_m: 0.0057 - precision_m: 0.0076 - val_loss: 0.4027 - val_acc: 0.8763 - val_auroc: 0.6516 - val_auprc: 0.2218 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 14/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3951 - acc: 0.8622 - auroc: 0.6525 - auprc: 0.2229 - f1_m: 0.0159 - recall_m: 0.0152 - precision_m: 0.0180 - val_loss: 0.4013 - val_acc: 0.8746 - val_auroc: 0.6531 - val_auprc: 0.2236 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 15/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3959 - acc: 0.8615 - auroc: 0.6531 - auprc: 0.2239 - f1_m: 0.0097 - recall_m: 0.0092 - precision_m: 0.0107 - val_loss: 0.4003 - val_acc: 0.8763 - val_auroc: 0.6541 - val_auprc: 0.2249 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 16/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3968 - acc: 0.8605 - auroc: 0.6548 - auprc: 0.2260 - f1_m: 0.0096 - recall_m: 0.0090 - precision_m: 0.0111 - val_loss: 0.3991 - val_acc: 0.8763 - val_auroc: 0.6553 - val_auprc: 0.2265 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 17/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3970 - acc: 0.8620 - auroc: 0.6554 - auprc: 0.2267 - f1_m: 0.0110 - recall_m: 0.0103 - precision_m: 0.0122 - val_loss: 0.3982 - val_acc: 0.8763 - val_auroc: 0.6562 - val_auprc: 0.2278 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 18/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3955 - acc: 0.8605 - auroc: 0.6567 - auprc: 0.2285 - f1_m: 0.0130 - recall_m: 0.0120 - precision_m: 0.0153 - val_loss: 0.3974 - val_acc: 0.8763 - val_auroc: 0.6571 - val_auprc: 0.2290 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 19/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3945 - acc: 0.8618 - auroc: 0.6577 - auprc: 0.2297 - f1_m: 0.0115 - recall_m: 0.0106 - precision_m: 0.0134 - val_loss: 0.3966 - val_acc: 0.8763 - val_auroc: 0.6582 - val_auprc: 0.2305 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 20/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3949 - acc: 0.8632 - auroc: 0.6587 - auprc: 0.2310 - f1_m: 0.0155 - recall_m: 0.0141 - precision_m: 0.0183 - val_loss: 0.3959 - val_acc: 0.8763 - val_auroc: 0.6591 - val_auprc: 0.2318 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 21/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3933 - acc: 0.8624 - auroc: 0.6596 - auprc: 0.2326 - f1_m: 0.0163 - recall_m: 0.0145 - precision_m: 0.0199 - val_loss: 0.3953 - val_acc: 0.8763 - val_auroc: 0.6599 - val_auprc: 0.2333 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 22/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3943 - acc: 0.8618 - auroc: 0.6608 - auprc: 0.2341 - f1_m: 0.0130 - recall_m: 0.0118 - precision_m: 0.0153 - val_loss: 0.3946 - val_acc: 0.8763 - val_auroc: 0.6608 - val_auprc: 0.2344 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 23/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3945 - acc: 0.8607 - auroc: 0.6612 - auprc: 0.2348 - f1_m: 0.0108 - recall_m: 0.0099 - precision_m: 0.0126 - val_loss: 0.3942 - val_acc: 0.8763 - val_auroc: 0.6614 - val_auprc: 0.2351 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 24/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3933 - acc: 0.8634 - auroc: 0.6616 - auprc: 0.2354 - f1_m: 0.0141 - recall_m: 0.0131 - precision_m: 0.0161 - val_loss: 0.3937 - val_acc: 0.8763 - val_auroc: 0.6620 - val_auprc: 0.2361 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 25/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3902 - acc: 0.8626 - auroc: 0.6627 - auprc: 0.2368 - f1_m: 0.0153 - recall_m: 0.0145 - precision_m: 0.0168 - val_loss: 0.3934 - val_acc: 0.8763 - val_auroc: 0.6629 - val_auprc: 0.2371 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 26/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3913 - acc: 0.8615 - auroc: 0.6634 - auprc: 0.2376 - f1_m: 0.0108 - recall_m: 0.0097 - precision_m: 0.0130 - val_loss: 0.3931 - val_acc: 0.8763 - val_auroc: 0.6636 - val_auprc: 0.2380 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 27/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3897 - acc: 0.8615 - auroc: 0.6640 - auprc: 0.2385 - f1_m: 0.0147 - recall_m: 0.0138 - precision_m: 0.0164 - val_loss: 0.3926 - val_acc: 0.8763 - val_auroc: 0.6645 - val_auprc: 0.2390 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 28/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3898 - acc: 0.8622 - auroc: 0.6651 - auprc: 0.2399 - f1_m: 0.0167 - recall_m: 0.0155 - precision_m: 0.0191 - val_loss: 0.3922 - val_acc: 0.8763 - val_auroc: 0.6653 - val_auprc: 0.2404 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 29/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3898 - acc: 0.8622 - auroc: 0.6655 - auprc: 0.2407 - f1_m: 0.0132 - recall_m: 0.0124 - precision_m: 0.0153 - val_loss: 0.3919 - val_acc: 0.8763 - val_auroc: 0.6659 - val_auprc: 0.2412 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 30/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3929 - acc: 0.8624 - auroc: 0.6661 - auprc: 0.2415 - f1_m: 0.0159 - recall_m: 0.0152 - precision_m: 0.0176 - val_loss: 0.3915 - val_acc: 0.8763 - val_auroc: 0.6664 - val_auprc: 0.2419 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 31/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3872 - acc: 0.8636 - auroc: 0.6668 - auprc: 0.2425 - f1_m: 0.0171 - recall_m: 0.0161 - precision_m: 0.0195 - val_loss: 0.3912 - val_acc: 0.8763 - val_auroc: 0.6672 - val_auprc: 0.2429 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 32/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3879 - acc: 0.8632 - auroc: 0.6676 - auprc: 0.2435 - f1_m: 0.0139 - recall_m: 0.0129 - precision_m: 0.0161 - val_loss: 0.3910 - val_acc: 0.8763 - val_auroc: 0.6680 - val_auprc: 0.2441 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 33/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3919 - acc: 0.8615 - auroc: 0.6684 - auprc: 0.2445 - f1_m: 0.0158 - recall_m: 0.0149 - precision_m: 0.0176 - val_loss: 0.3908 - val_acc: 0.8763 - val_auroc: 0.6683 - val_auprc: 0.2448 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 34/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3872 - acc: 0.8630 - auroc: 0.6688 - auprc: 0.2452 - f1_m: 0.0197 - recall_m: 0.0190 - precision_m: 0.0214 - val_loss: 0.3904 - val_acc: 0.8763 - val_auroc: 0.6690 - val_auprc: 0.2457 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 35/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3878 - acc: 0.8622 - auroc: 0.6693 - auprc: 0.2461 - f1_m: 0.0154 - recall_m: 0.0148 - precision_m: 0.0172 - val_loss: 0.3902 - val_acc: 0.8763 - val_auroc: 0.6697 - val_auprc: 0.2466 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 36/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3898 - acc: 0.8634 - auroc: 0.6699 - auprc: 0.2470 - f1_m: 0.0209 - recall_m: 0.0203 - precision_m: 0.0222 - val_loss: 0.3900 - val_acc: 0.8763 - val_auroc: 0.6702 - val_auprc: 0.2474 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 37/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3880 - acc: 0.8634 - auroc: 0.6705 - auprc: 0.2478 - f1_m: 0.0145 - recall_m: 0.0138 - precision_m: 0.0164 - val_loss: 0.3897 - val_acc: 0.8763 - val_auroc: 0.6706 - val_auprc: 0.2481 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 38/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3891 - acc: 0.8620 - auroc: 0.6708 - auprc: 0.2485 - f1_m: 0.0171 - recall_m: 0.0159 - precision_m: 0.0195 - val_loss: 0.3894 - val_acc: 0.8763 - val_auroc: 0.6710 - val_auprc: 0.2488 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 39/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3859 - acc: 0.8630 - auroc: 0.6713 - auprc: 0.2491 - f1_m: 0.0159 - recall_m: 0.0147 - precision_m: 0.0191 - val_loss: 0.3893 - val_acc: 0.8763 - val_auroc: 0.6716 - val_auprc: 0.2495 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 40/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3930 - acc: 0.8626 - auroc: 0.6716 - auprc: 0.2499 - f1_m: 0.0155 - recall_m: 0.0145 - precision_m: 0.0176 - val_loss: 0.3891 - val_acc: 0.8763 - val_auroc: 0.6717 - val_auprc: 0.2502 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 41/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3881 - acc: 0.8626 - auroc: 0.6720 - auprc: 0.2506 - f1_m: 0.0182 - recall_m: 0.0172 - precision_m: 0.0203 - val_loss: 0.3888 - val_acc: 0.8763 - val_auroc: 0.6721 - val_auprc: 0.2508 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 42/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3879 - acc: 0.8613 - auroc: 0.6723 - auprc: 0.2512 - f1_m: 0.0163 - recall_m: 0.0149 - precision_m: 0.0191 - val_loss: 0.3887 - val_acc: 0.8763 - val_auroc: 0.6725 - val_auprc: 0.2515 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 43/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3856 - acc: 0.8632 - auroc: 0.6728 - auprc: 0.2518 - f1_m: 0.0179 - recall_m: 0.0166 - precision_m: 0.0206 - val_loss: 0.3885 - val_acc: 0.8763 - val_auroc: 0.6729 - val_auprc: 0.2521 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 44/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3871 - acc: 0.8616 - auroc: 0.6732 - auprc: 0.2524 - f1_m: 0.0132 - recall_m: 0.0126 - precision_m: 0.0145 - val_loss: 0.3883 - val_acc: 0.8763 - val_auroc: 0.6734 - val_auprc: 0.2526 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 45/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3881 - acc: 0.8622 - auroc: 0.6735 - auprc: 0.2530 - f1_m: 0.0155 - recall_m: 0.0148 - precision_m: 0.0172 - val_loss: 0.3883 - val_acc: 0.8763 - val_auroc: 0.6737 - val_auprc: 0.2531 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 46/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3880 - acc: 0.8618 - auroc: 0.6740 - auprc: 0.2534 - f1_m: 0.0145 - recall_m: 0.0138 - precision_m: 0.0161 - val_loss: 0.3881 - val_acc: 0.8763 - val_auroc: 0.6740 - val_auprc: 0.2536 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 47/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3897 - acc: 0.8626 - auroc: 0.6742 - auprc: 0.2539 - f1_m: 0.0186 - recall_m: 0.0176 - precision_m: 0.0206 - val_loss: 0.3879 - val_acc: 0.8763 - val_auroc: 0.6743 - val_auprc: 0.2540 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 48/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3887 - acc: 0.8626 - auroc: 0.6745 - auprc: 0.2542 - f1_m: 0.0153 - recall_m: 0.0143 - precision_m: 0.0176 - val_loss: 0.3878 - val_acc: 0.8763 - val_auroc: 0.6746 - val_auprc: 0.2545 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 49/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3865 - acc: 0.8622 - auroc: 0.6748 - auprc: 0.2548 - f1_m: 0.0161 - recall_m: 0.0148 - precision_m: 0.0195 - val_loss: 0.3876 - val_acc: 0.8763 - val_auroc: 0.6750 - val_auprc: 0.2551 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 50/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3869 - acc: 0.8632 - auroc: 0.6753 - auprc: 0.2555 - f1_m: 0.0203 - recall_m: 0.0190 - precision_m: 0.0233 - val_loss: 0.3875 - val_acc: 0.8763 - val_auroc: 0.6753 - val_auprc: 0.2556 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 51/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3875 - acc: 0.8626 - auroc: 0.6755 - auprc: 0.2558 - f1_m: 0.0130 - recall_m: 0.0116 - precision_m: 0.0161 - val_loss: 0.3874 - val_acc: 0.8763 - val_auroc: 0.6756 - val_auprc: 0.2561 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 52/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3859 - acc: 0.8616 - auroc: 0.6758 - auprc: 0.2565 - f1_m: 0.0147 - recall_m: 0.0136 - precision_m: 0.0168 - val_loss: 0.3872 - val_acc: 0.8763 - val_auroc: 0.6759 - val_auprc: 0.2566 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 53/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3841 - acc: 0.8634 - auroc: 0.6762 - auprc: 0.2569 - f1_m: 0.0185 - recall_m: 0.0175 - precision_m: 0.0206 - val_loss: 0.3871 - val_acc: 0.8763 - val_auroc: 0.6763 - val_auprc: 0.2572 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 54/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3859 - acc: 0.8622 - auroc: 0.6765 - auprc: 0.2574 - f1_m: 0.0150 - recall_m: 0.0141 - precision_m: 0.0168 - val_loss: 0.3870 - val_acc: 0.8763 - val_auroc: 0.6766 - val_auprc: 0.2577 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 55/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3857 - acc: 0.8624 - auroc: 0.6768 - auprc: 0.2580 - f1_m: 0.0157 - recall_m: 0.0149 - precision_m: 0.0172 - val_loss: 0.3869 - val_acc: 0.8763 - val_auroc: 0.6769 - val_auprc: 0.2582 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 56/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3871 - acc: 0.8628 - auroc: 0.6771 - auprc: 0.2585 - f1_m: 0.0219 - recall_m: 0.0210 - precision_m: 0.0237 - val_loss: 0.3867 - val_acc: 0.8763 - val_auroc: 0.6772 - val_auprc: 0.2586 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 57/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3863 - acc: 0.8630 - auroc: 0.6774 - auprc: 0.2588 - f1_m: 0.0162 - recall_m: 0.0152 - precision_m: 0.0187 - val_loss: 0.3866 - val_acc: 0.8763 - val_auroc: 0.6775 - val_auprc: 0.2590 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 58/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3833 - acc: 0.8632 - auroc: 0.6777 - auprc: 0.2593 - f1_m: 0.0201 - recall_m: 0.0191 - precision_m: 0.0222 - val_loss: 0.3866 - val_acc: 0.8763 - val_auroc: 0.6779 - val_auprc: 0.2595 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 59/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3876 - acc: 0.8628 - auroc: 0.6779 - auprc: 0.2597 - f1_m: 0.0203 - recall_m: 0.0192 - precision_m: 0.0229 - val_loss: 0.3865 - val_acc: 0.8763 - val_auroc: 0.6780 - val_auprc: 0.2598 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 60/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3875 - acc: 0.8634 - auroc: 0.6782 - auprc: 0.2601 - f1_m: 0.0176 - recall_m: 0.0163 - precision_m: 0.0203 - val_loss: 0.3863 - val_acc: 0.8763 - val_auroc: 0.6783 - val_auprc: 0.2603 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 61/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3849 - acc: 0.8626 - auroc: 0.6785 - auprc: 0.2605 - f1_m: 0.0178 - recall_m: 0.0166 - precision_m: 0.0206 - val_loss: 0.3862 - val_acc: 0.8763 - val_auroc: 0.6786 - val_auprc: 0.2607 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 62/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3885 - acc: 0.8616 - auroc: 0.6787 - auprc: 0.2608 - f1_m: 0.0168 - recall_m: 0.0158 - precision_m: 0.0191 - val_loss: 0.3861 - val_acc: 0.8763 - val_auroc: 0.6788 - val_auprc: 0.2609 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 63/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3868 - acc: 0.8630 - auroc: 0.6789 - auprc: 0.2611 - f1_m: 0.0209 - recall_m: 0.0203 - precision_m: 0.0225 - val_loss: 0.3860 - val_acc: 0.8763 - val_auroc: 0.6790 - val_auprc: 0.2613 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 64/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3836 - acc: 0.8622 - auroc: 0.6791 - auprc: 0.2615 - f1_m: 0.0161 - recall_m: 0.0153 - precision_m: 0.0176 - val_loss: 0.3859 - val_acc: 0.8763 - val_auroc: 0.6793 - val_auprc: 0.2617 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 65/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3853 - acc: 0.8634 - auroc: 0.6795 - auprc: 0.2620 - f1_m: 0.0180 - recall_m: 0.0173 - precision_m: 0.0195 - val_loss: 0.3858 - val_acc: 0.8763 - val_auroc: 0.6796 - val_auprc: 0.2622 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 66/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3866 - acc: 0.8634 - auroc: 0.6797 - auprc: 0.2624 - f1_m: 0.0161 - recall_m: 0.0149 - precision_m: 0.0183 - val_loss: 0.3857 - val_acc: 0.8763 - val_auroc: 0.6798 - val_auprc: 0.2625 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 67/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3833 - acc: 0.8628 - auroc: 0.6799 - auprc: 0.2627 - f1_m: 0.0196 - recall_m: 0.0183 - precision_m: 0.0222 - val_loss: 0.3856 - val_acc: 0.8763 - val_auroc: 0.6801 - val_auprc: 0.2630 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 68/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3863 - acc: 0.8624 - auroc: 0.6803 - auprc: 0.2632 - f1_m: 0.0175 - recall_m: 0.0153 - precision_m: 0.0222 - val_loss: 0.3855 - val_acc: 0.8763 - val_auroc: 0.6802 - val_auprc: 0.2632 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 69/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3866 - acc: 0.8628 - auroc: 0.6803 - auprc: 0.2634 - f1_m: 0.0168 - recall_m: 0.0161 - precision_m: 0.0183 - val_loss: 0.3854 - val_acc: 0.8763 - val_auroc: 0.6804 - val_auprc: 0.2636 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 70/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3832 - acc: 0.8630 - auroc: 0.6806 - auprc: 0.2637 - f1_m: 0.0162 - recall_m: 0.0148 - precision_m: 0.0195 - val_loss: 0.3853 - val_acc: 0.8763 - val_auroc: 0.6807 - val_auprc: 0.2640 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 71/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3864 - acc: 0.8630 - auroc: 0.6809 - auprc: 0.2641 - f1_m: 0.0167 - recall_m: 0.0153 - precision_m: 0.0199 - val_loss: 0.3852 - val_acc: 0.8763 - val_auroc: 0.6809 - val_auprc: 0.2642 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 72/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3859 - acc: 0.8643 - auroc: 0.6810 - auprc: 0.2644 - f1_m: 0.0211 - recall_m: 0.0192 - precision_m: 0.0252 - val_loss: 0.3851 - val_acc: 0.8763 - val_auroc: 0.6810 - val_auprc: 0.2645 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 73/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3830 - acc: 0.8634 - auroc: 0.6811 - auprc: 0.2647 - f1_m: 0.0147 - recall_m: 0.0129 - precision_m: 0.0183 - val_loss: 0.3850 - val_acc: 0.8763 - val_auroc: 0.6812 - val_auprc: 0.2649 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 74/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3845 - acc: 0.8641 - auroc: 0.6814 - auprc: 0.2651 - f1_m: 0.0184 - recall_m: 0.0169 - precision_m: 0.0216 - val_loss: 0.3849 - val_acc: 0.8763 - val_auroc: 0.6815 - val_auprc: 0.2653 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 75/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3848 - acc: 0.8632 - auroc: 0.6816 - auprc: 0.2655 - f1_m: 0.0192 - recall_m: 0.0190 - precision_m: 0.0206 - val_loss: 0.3848 - val_acc: 0.8763 - val_auroc: 0.6817 - val_auprc: 0.2656 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 76/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3848 - acc: 0.8618 - auroc: 0.6818 - auprc: 0.2658 - f1_m: 0.0172 - recall_m: 0.0164 - precision_m: 0.0195 - val_loss: 0.3848 - val_acc: 0.8763 - val_auroc: 0.6819 - val_auprc: 0.2660 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 77/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3814 - acc: 0.8647 - auroc: 0.6820 - auprc: 0.2662 - f1_m: 0.0200 - recall_m: 0.0189 - precision_m: 0.0229 - val_loss: 0.3847 - val_acc: 0.8763 - val_auroc: 0.6822 - val_auprc: 0.2664 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 78/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3824 - acc: 0.8622 - auroc: 0.6823 - auprc: 0.2666 - f1_m: 0.0171 - recall_m: 0.0152 - precision_m: 0.0214 - val_loss: 0.3846 - val_acc: 0.8763 - val_auroc: 0.6824 - val_auprc: 0.2668 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 79/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3819 - acc: 0.8618 - auroc: 0.6826 - auprc: 0.2670 - f1_m: 0.0169 - recall_m: 0.0155 - precision_m: 0.0199 - val_loss: 0.3845 - val_acc: 0.8763 - val_auroc: 0.6827 - val_auprc: 0.2671 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 80/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3869 - acc: 0.8613 - auroc: 0.6827 - auprc: 0.2671 - f1_m: 0.0159 - recall_m: 0.0145 - precision_m: 0.0191 - val_loss: 0.3845 - val_acc: 0.8763 - val_auroc: 0.6828 - val_auprc: 0.2673 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 81/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3835 - acc: 0.8630 - auroc: 0.6829 - auprc: 0.2674 - f1_m: 0.0199 - recall_m: 0.0178 - precision_m: 0.0245 - val_loss: 0.3844 - val_acc: 0.8763 - val_auroc: 0.6830 - val_auprc: 0.2676 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 82/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3819 - acc: 0.8632 - auroc: 0.6831 - auprc: 0.2677 - f1_m: 0.0197 - recall_m: 0.0186 - precision_m: 0.0222 - val_loss: 0.3843 - val_acc: 0.8763 - val_auroc: 0.6832 - val_auprc: 0.2679 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 83/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3822 - acc: 0.8630 - auroc: 0.6833 - auprc: 0.2681 - f1_m: 0.0205 - recall_m: 0.0201 - precision_m: 0.0218 - val_loss: 0.3842 - val_acc: 0.8763 - val_auroc: 0.6834 - val_auprc: 0.2683 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 84/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3826 - acc: 0.8632 - auroc: 0.6836 - auprc: 0.2685 - f1_m: 0.0225 - recall_m: 0.0213 - precision_m: 0.0260 - val_loss: 0.3842 - val_acc: 0.8763 - val_auroc: 0.6836 - val_auprc: 0.2686 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 85/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3818 - acc: 0.8609 - auroc: 0.6837 - auprc: 0.2687 - f1_m: 0.0138 - recall_m: 0.0124 - precision_m: 0.0168 - val_loss: 0.3841 - val_acc: 0.8763 - val_auroc: 0.6838 - val_auprc: 0.2688 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 86/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3841 - acc: 0.8624 - auroc: 0.6839 - auprc: 0.2689 - f1_m: 0.0172 - recall_m: 0.0167 - precision_m: 0.0191 - val_loss: 0.3840 - val_acc: 0.8763 - val_auroc: 0.6840 - val_auprc: 0.2691 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 87/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3875 - acc: 0.8636 - auroc: 0.6840 - auprc: 0.2692 - f1_m: 0.0215 - recall_m: 0.0206 - precision_m: 0.0241 - val_loss: 0.3839 - val_acc: 0.8763 - val_auroc: 0.6841 - val_auprc: 0.2694 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 88/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3818 - acc: 0.8632 - auroc: 0.6842 - auprc: 0.2696 - f1_m: 0.0183 - recall_m: 0.0166 - precision_m: 0.0222 - val_loss: 0.3838 - val_acc: 0.8763 - val_auroc: 0.6843 - val_auprc: 0.2697 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 89/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3823 - acc: 0.8647 - auroc: 0.6844 - auprc: 0.2700 - f1_m: 0.0231 - recall_m: 0.0217 - precision_m: 0.0260 - val_loss: 0.3837 - val_acc: 0.8763 - val_auroc: 0.6845 - val_auprc: 0.2700 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 90/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3832 - acc: 0.8637 - auroc: 0.6846 - auprc: 0.2702 - f1_m: 0.0192 - recall_m: 0.0173 - precision_m: 0.0237 - val_loss: 0.3837 - val_acc: 0.8763 - val_auroc: 0.6846 - val_auprc: 0.2703 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 91/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3823 - acc: 0.8637 - auroc: 0.6847 - auprc: 0.2705 - f1_m: 0.0185 - recall_m: 0.0168 - precision_m: 0.0222 - val_loss: 0.3836 - val_acc: 0.8763 - val_auroc: 0.6848 - val_auprc: 0.2706 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 92/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3844 - acc: 0.8620 - auroc: 0.6849 - auprc: 0.2707 - f1_m: 0.0182 - recall_m: 0.0171 - precision_m: 0.0206 - val_loss: 0.3835 - val_acc: 0.8763 - val_auroc: 0.6850 - val_auprc: 0.2708 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 93/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3836 - acc: 0.8639 - auroc: 0.6850 - auprc: 0.2709 - f1_m: 0.0204 - recall_m: 0.0190 - precision_m: 0.0237 - val_loss: 0.3835 - val_acc: 0.8763 - val_auroc: 0.6851 - val_auprc: 0.2710 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 94/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3806 - acc: 0.8636 - auroc: 0.6852 - auprc: 0.2711 - f1_m: 0.0198 - recall_m: 0.0184 - precision_m: 0.0229 - val_loss: 0.3834 - val_acc: 0.8763 - val_auroc: 0.6853 - val_auprc: 0.2712 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 95/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3813 - acc: 0.8624 - auroc: 0.6855 - auprc: 0.2714 - f1_m: 0.0189 - recall_m: 0.0179 - precision_m: 0.0218 - val_loss: 0.3833 - val_acc: 0.8763 - val_auroc: 0.6856 - val_auprc: 0.2715 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 96/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3840 - acc: 0.8630 - auroc: 0.6857 - auprc: 0.2717 - f1_m: 0.0217 - recall_m: 0.0199 - precision_m: 0.0252 - val_loss: 0.3832 - val_acc: 0.8763 - val_auroc: 0.6857 - val_auprc: 0.2718 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 97/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3808 - acc: 0.8626 - auroc: 0.6858 - auprc: 0.2718 - f1_m: 0.0151 - recall_m: 0.0141 - precision_m: 0.0176 - val_loss: 0.3832 - val_acc: 0.8763 - val_auroc: 0.6859 - val_auprc: 0.2720 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 98/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3845 - acc: 0.8616 - auroc: 0.6859 - auprc: 0.2721 - f1_m: 0.0157 - recall_m: 0.0148 - precision_m: 0.0176 - val_loss: 0.3831 - val_acc: 0.8763 - val_auroc: 0.6860 - val_auprc: 0.2722 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 99/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3845 - acc: 0.8626 - auroc: 0.6861 - auprc: 0.2723 - f1_m: 0.0190 - recall_m: 0.0178 - precision_m: 0.0214 - val_loss: 0.3831 - val_acc: 0.8763 - val_auroc: 0.6861 - val_auprc: 0.2724 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 100/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3836 - acc: 0.8615 - auroc: 0.6862 - auprc: 0.2725 - f1_m: 0.0172 - recall_m: 0.0166 - precision_m: 0.0191 - val_loss: 0.3830 - val_acc: 0.8763 - val_auroc: 0.6862 - val_auprc: 0.2726 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# forebrain validation accuracy is: 0.8349097162510748
# Train on 5233 samples, validate on 582 samples
# Epoch 1/100
# 5233/5233 [==============================] - 23s 4ms/step - loss: 0.6967 - acc: 0.7749 - auroc: 0.6606 - auprc: 0.2363 - f1_m: 0.1314 - recall_m: 0.1519 - precision_m: 0.1280 - val_loss: 0.5514 - val_acc: 0.8660 - val_auroc: 0.6558 - val_auprc: 0.2251 - val_f1_m: 0.0206 - val_recall_m: 0.0206 - val_precision_m: 0.0206
# Epoch 2/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4706 - acc: 0.8563 - auroc: 0.6542 - auprc: 0.2217 - f1_m: 0.0200 - recall_m: 0.0189 - precision_m: 0.0222 - val_loss: 0.4826 - val_acc: 0.8694 - val_auroc: 0.6496 - val_auprc: 0.2181 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 3/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4457 - acc: 0.8573 - auroc: 0.6461 - auprc: 0.2140 - f1_m: 0.0046 - recall_m: 0.0046 - precision_m: 0.0046 - val_loss: 0.4584 - val_acc: 0.8711 - val_auroc: 0.6435 - val_auprc: 0.2126 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 4/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4326 - acc: 0.8569 - auroc: 0.6419 - auprc: 0.2116 - f1_m: 0.0050 - recall_m: 0.0048 - precision_m: 0.0054 - val_loss: 0.4418 - val_acc: 0.8711 - val_auroc: 0.6405 - val_auprc: 0.2112 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 5/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4269 - acc: 0.8594 - auroc: 0.6411 - auprc: 0.2119 - f1_m: 0.0127 - recall_m: 0.0122 - precision_m: 0.0138 - val_loss: 0.4310 - val_acc: 0.8711 - val_auroc: 0.6393 - val_auprc: 0.2114 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 6/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4202 - acc: 0.8590 - auroc: 0.6404 - auprc: 0.2133 - f1_m: 0.0124 - recall_m: 0.0117 - precision_m: 0.0138 - val_loss: 0.4233 - val_acc: 0.8711 - val_auroc: 0.6393 - val_auprc: 0.2130 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 7/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4175 - acc: 0.8584 - auroc: 0.6395 - auprc: 0.2127 - f1_m: 0.0054 - recall_m: 0.0050 - precision_m: 0.0061 - val_loss: 0.4183 - val_acc: 0.8746 - val_auroc: 0.6395 - val_auprc: 0.2139 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 8/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4125 - acc: 0.8573 - auroc: 0.6400 - auprc: 0.2150 - f1_m: 0.0117 - recall_m: 0.0115 - precision_m: 0.0122 - val_loss: 0.4147 - val_acc: 0.8729 - val_auroc: 0.6404 - val_auprc: 0.2156 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 9/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4135 - acc: 0.8588 - auroc: 0.6409 - auprc: 0.2163 - f1_m: 0.0139 - recall_m: 0.0132 - precision_m: 0.0153 - val_loss: 0.4119 - val_acc: 0.8729 - val_auroc: 0.6414 - val_auprc: 0.2169 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 10/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4093 - acc: 0.8582 - auroc: 0.6417 - auprc: 0.2173 - f1_m: 0.0125 - recall_m: 0.0117 - precision_m: 0.0145 - val_loss: 0.4100 - val_acc: 0.8729 - val_auroc: 0.6423 - val_auprc: 0.2182 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 11/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4048 - acc: 0.8603 - auroc: 0.6427 - auprc: 0.2192 - f1_m: 0.0143 - recall_m: 0.0130 - precision_m: 0.0168 - val_loss: 0.4086 - val_acc: 0.8729 - val_auroc: 0.6437 - val_auprc: 0.2201 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 12/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4095 - acc: 0.8590 - auroc: 0.6441 - auprc: 0.2207 - f1_m: 0.0169 - recall_m: 0.0159 - precision_m: 0.0195 - val_loss: 0.4070 - val_acc: 0.8746 - val_auroc: 0.6444 - val_auprc: 0.2215 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 13/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4025 - acc: 0.8586 - auroc: 0.6454 - auprc: 0.2220 - f1_m: 0.0127 - recall_m: 0.0120 - precision_m: 0.0145 - val_loss: 0.4057 - val_acc: 0.8746 - val_auroc: 0.6460 - val_auprc: 0.2231 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 14/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4099 - acc: 0.8576 - auroc: 0.6463 - auprc: 0.2236 - f1_m: 0.0127 - recall_m: 0.0118 - precision_m: 0.0145 - val_loss: 0.4044 - val_acc: 0.8729 - val_auroc: 0.6468 - val_auprc: 0.2246 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 15/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4078 - acc: 0.8580 - auroc: 0.6471 - auprc: 0.2252 - f1_m: 0.0139 - recall_m: 0.0127 - precision_m: 0.0168 - val_loss: 0.4036 - val_acc: 0.8729 - val_auroc: 0.6475 - val_auprc: 0.2259 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 16/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4023 - acc: 0.8586 - auroc: 0.6482 - auprc: 0.2266 - f1_m: 0.0120 - recall_m: 0.0111 - precision_m: 0.0138 - val_loss: 0.4029 - val_acc: 0.8729 - val_auroc: 0.6487 - val_auprc: 0.2274 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 17/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4048 - acc: 0.8595 - auroc: 0.6494 - auprc: 0.2283 - f1_m: 0.0169 - recall_m: 0.0159 - precision_m: 0.0191 - val_loss: 0.4020 - val_acc: 0.8729 - val_auroc: 0.6497 - val_auprc: 0.2289 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 18/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4030 - acc: 0.8592 - auroc: 0.6502 - auprc: 0.2298 - f1_m: 0.0210 - recall_m: 0.0197 - precision_m: 0.0241 - val_loss: 0.4015 - val_acc: 0.8729 - val_auroc: 0.6505 - val_auprc: 0.2303 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 19/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4026 - acc: 0.8592 - auroc: 0.6511 - auprc: 0.2309 - f1_m: 0.0162 - recall_m: 0.0149 - precision_m: 0.0191 - val_loss: 0.4009 - val_acc: 0.8729 - val_auroc: 0.6514 - val_auprc: 0.2313 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 20/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4015 - acc: 0.8595 - auroc: 0.6522 - auprc: 0.2321 - f1_m: 0.0152 - recall_m: 0.0136 - precision_m: 0.0183 - val_loss: 0.4004 - val_acc: 0.8729 - val_auroc: 0.6524 - val_auprc: 0.2326 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 21/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4023 - acc: 0.8586 - auroc: 0.6531 - auprc: 0.2332 - f1_m: 0.0143 - recall_m: 0.0134 - precision_m: 0.0161 - val_loss: 0.3998 - val_acc: 0.8729 - val_auroc: 0.6532 - val_auprc: 0.2336 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 22/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3995 - acc: 0.8607 - auroc: 0.6539 - auprc: 0.2343 - f1_m: 0.0181 - recall_m: 0.0166 - precision_m: 0.0214 - val_loss: 0.3995 - val_acc: 0.8729 - val_auroc: 0.6542 - val_auprc: 0.2348 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 23/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3990 - acc: 0.8595 - auroc: 0.6547 - auprc: 0.2355 - f1_m: 0.0169 - recall_m: 0.0163 - precision_m: 0.0183 - val_loss: 0.3992 - val_acc: 0.8729 - val_auroc: 0.6550 - val_auprc: 0.2361 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 24/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3995 - acc: 0.8590 - auroc: 0.6554 - auprc: 0.2366 - f1_m: 0.0141 - recall_m: 0.0129 - precision_m: 0.0168 - val_loss: 0.3990 - val_acc: 0.8729 - val_auroc: 0.6557 - val_auprc: 0.2372 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 25/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3994 - acc: 0.8592 - auroc: 0.6561 - auprc: 0.2378 - f1_m: 0.0152 - recall_m: 0.0144 - precision_m: 0.0168 - val_loss: 0.3985 - val_acc: 0.8729 - val_auroc: 0.6567 - val_auprc: 0.2385 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 26/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3986 - acc: 0.8586 - auroc: 0.6571 - auprc: 0.2390 - f1_m: 0.0176 - recall_m: 0.0163 - precision_m: 0.0206 - val_loss: 0.3981 - val_acc: 0.8729 - val_auroc: 0.6575 - val_auprc: 0.2395 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 27/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3955 - acc: 0.8601 - auroc: 0.6582 - auprc: 0.2402 - f1_m: 0.0176 - recall_m: 0.0159 - precision_m: 0.0214 - val_loss: 0.3978 - val_acc: 0.8729 - val_auroc: 0.6585 - val_auprc: 0.2407 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 28/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3958 - acc: 0.8586 - auroc: 0.6589 - auprc: 0.2414 - f1_m: 0.0166 - recall_m: 0.0159 - precision_m: 0.0183 - val_loss: 0.3976 - val_acc: 0.8729 - val_auroc: 0.6592 - val_auprc: 0.2417 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 29/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3996 - acc: 0.8605 - auroc: 0.6593 - auprc: 0.2420 - f1_m: 0.0186 - recall_m: 0.0171 - precision_m: 0.0222 - val_loss: 0.3974 - val_acc: 0.8729 - val_auroc: 0.6597 - val_auprc: 0.2425 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 30/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3961 - acc: 0.8594 - auroc: 0.6600 - auprc: 0.2428 - f1_m: 0.0162 - recall_m: 0.0155 - precision_m: 0.0176 - val_loss: 0.3973 - val_acc: 0.8729 - val_auroc: 0.6604 - val_auprc: 0.2433 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 31/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3986 - acc: 0.8601 - auroc: 0.6608 - auprc: 0.2439 - f1_m: 0.0175 - recall_m: 0.0163 - precision_m: 0.0199 - val_loss: 0.3970 - val_acc: 0.8729 - val_auroc: 0.6610 - val_auprc: 0.2442 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 32/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3998 - acc: 0.8595 - auroc: 0.6613 - auprc: 0.2445 - f1_m: 0.0206 - recall_m: 0.0191 - precision_m: 0.0237 - val_loss: 0.3967 - val_acc: 0.8729 - val_auroc: 0.6615 - val_auprc: 0.2450 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 33/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3980 - acc: 0.8603 - auroc: 0.6619 - auprc: 0.2453 - f1_m: 0.0159 - recall_m: 0.0149 - precision_m: 0.0183 - val_loss: 0.3965 - val_acc: 0.8729 - val_auroc: 0.6620 - val_auprc: 0.2458 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 34/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3957 - acc: 0.8609 - auroc: 0.6624 - auprc: 0.2463 - f1_m: 0.0246 - recall_m: 0.0236 - precision_m: 0.0268 - val_loss: 0.3963 - val_acc: 0.8729 - val_auroc: 0.6626 - val_auprc: 0.2467 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 35/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3990 - acc: 0.8603 - auroc: 0.6629 - auprc: 0.2472 - f1_m: 0.0227 - recall_m: 0.0217 - precision_m: 0.0248 - val_loss: 0.3960 - val_acc: 0.8729 - val_auroc: 0.6630 - val_auprc: 0.2473 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 36/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3967 - acc: 0.8605 - auroc: 0.6634 - auprc: 0.2476 - f1_m: 0.0210 - recall_m: 0.0192 - precision_m: 0.0245 - val_loss: 0.3959 - val_acc: 0.8729 - val_auroc: 0.6635 - val_auprc: 0.2480 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 37/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3970 - acc: 0.8594 - auroc: 0.6638 - auprc: 0.2482 - f1_m: 0.0183 - recall_m: 0.0173 - precision_m: 0.0206 - val_loss: 0.3958 - val_acc: 0.8729 - val_auroc: 0.6640 - val_auprc: 0.2486 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 38/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3972 - acc: 0.8595 - auroc: 0.6643 - auprc: 0.2489 - f1_m: 0.0157 - recall_m: 0.0145 - precision_m: 0.0183 - val_loss: 0.3957 - val_acc: 0.8729 - val_auroc: 0.6645 - val_auprc: 0.2492 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 39/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3995 - acc: 0.8588 - auroc: 0.6646 - auprc: 0.2495 - f1_m: 0.0181 - recall_m: 0.0176 - precision_m: 0.0195 - val_loss: 0.3955 - val_acc: 0.8729 - val_auroc: 0.6647 - val_auprc: 0.2498 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 40/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3942 - acc: 0.8586 - auroc: 0.6649 - auprc: 0.2502 - f1_m: 0.0185 - recall_m: 0.0183 - precision_m: 0.0195 - val_loss: 0.3953 - val_acc: 0.8729 - val_auroc: 0.6652 - val_auprc: 0.2505 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 41/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3975 - acc: 0.8603 - auroc: 0.6654 - auprc: 0.2509 - f1_m: 0.0197 - recall_m: 0.0180 - precision_m: 0.0237 - val_loss: 0.3951 - val_acc: 0.8729 - val_auroc: 0.6656 - val_auprc: 0.2512 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 42/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.3974 - acc: 0.8586 - auroc: 0.6657 - auprc: 0.2515 - f1_m: 0.0158 - recall_m: 0.0143 - precision_m: 0.0191 - val_loss: 0.3950 - val_acc: 0.8729 - val_auroc: 0.6661 - val_auprc: 0.2517 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 43/100
# ...
# Epoch 12/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4298 - acc: 0.8464 - auroc: 0.6492 - auprc: 0.2373 - f1_m: 0.0104 - recall_m: 0.0092 - precision_m: 0.0130 - val_loss: 0.3692 - val_acc: 0.8660 - val_auroc: 0.6503 - val_auprc: 0.2386 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 13/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4343 - acc: 0.8448 - auroc: 0.6509 - auprc: 0.2398 - f1_m: 0.0155 - recall_m: 0.0150 - precision_m: 0.0172 - val_loss: 0.3689 - val_acc: 0.8660 - val_auroc: 0.6512 - val_auprc: 0.2402 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 14/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4278 - acc: 0.8467 - auroc: 0.6520 - auprc: 0.2412 - f1_m: 0.0206 - recall_m: 0.0200 - precision_m: 0.0225 - val_loss: 0.3680 - val_acc: 0.8660 - val_auroc: 0.6525 - val_auprc: 0.2418 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 15/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4209 - acc: 0.8464 - auroc: 0.6535 - auprc: 0.2426 - f1_m: 0.0172 - recall_m: 0.0161 - precision_m: 0.0203 - val_loss: 0.3675 - val_acc: 0.8660 - val_auroc: 0.6540 - val_auprc: 0.2435 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 16/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4240 - acc: 0.8460 - auroc: 0.6549 - auprc: 0.2449 - f1_m: 0.0176 - recall_m: 0.0163 - precision_m: 0.0203 - val_loss: 0.3664 - val_acc: 0.8660 - val_auroc: 0.6556 - val_auprc: 0.2454 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 17/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4254 - acc: 0.8458 - auroc: 0.6562 - auprc: 0.2465 - f1_m: 0.0158 - recall_m: 0.0147 - precision_m: 0.0187 - val_loss: 0.3660 - val_acc: 0.8660 - val_auroc: 0.6568 - val_auprc: 0.2469 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 18/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4230 - acc: 0.8473 - auroc: 0.6573 - auprc: 0.2475 - f1_m: 0.0172 - recall_m: 0.0158 - precision_m: 0.0203 - val_loss: 0.3658 - val_acc: 0.8677 - val_auroc: 0.6579 - val_auprc: 0.2485 - val_f1_m: 0.0069 - val_recall_m: 0.0069 - val_precision_m: 0.0069
# Epoch 19/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4247 - acc: 0.8441 - auroc: 0.6585 - auprc: 0.2491 - f1_m: 0.0120 - recall_m: 0.0108 - precision_m: 0.0145 - val_loss: 0.3654 - val_acc: 0.8694 - val_auroc: 0.6590 - val_auprc: 0.2499 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 20/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4233 - acc: 0.8460 - auroc: 0.6595 - auprc: 0.2504 - f1_m: 0.0193 - recall_m: 0.0180 - precision_m: 0.0224 - val_loss: 0.3649 - val_acc: 0.8694 - val_auroc: 0.6600 - val_auprc: 0.2511 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 21/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4218 - acc: 0.8473 - auroc: 0.6603 - auprc: 0.2516 - f1_m: 0.0203 - recall_m: 0.0187 - precision_m: 0.0237 - val_loss: 0.3642 - val_acc: 0.8694 - val_auroc: 0.6611 - val_auprc: 0.2525 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 22/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4211 - acc: 0.8466 - auroc: 0.6616 - auprc: 0.2532 - f1_m: 0.0241 - recall_m: 0.0220 - precision_m: 0.0283 - val_loss: 0.3639 - val_acc: 0.8694 - val_auroc: 0.6621 - val_auprc: 0.2537 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 23/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4242 - acc: 0.8479 - auroc: 0.6625 - auprc: 0.2544 - f1_m: 0.0228 - recall_m: 0.0217 - precision_m: 0.0252 - val_loss: 0.3635 - val_acc: 0.8694 - val_auroc: 0.6630 - val_auprc: 0.2550 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 24/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4219 - acc: 0.8464 - auroc: 0.6634 - auprc: 0.2557 - f1_m: 0.0187 - recall_m: 0.0178 - precision_m: 0.0208 - val_loss: 0.3632 - val_acc: 0.8694 - val_auroc: 0.6639 - val_auprc: 0.2562 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 25/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4195 - acc: 0.8466 - auroc: 0.6645 - auprc: 0.2570 - f1_m: 0.0213 - recall_m: 0.0205 - precision_m: 0.0229 - val_loss: 0.3627 - val_acc: 0.8694 - val_auroc: 0.6649 - val_auprc: 0.2575 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 26/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4210 - acc: 0.8469 - auroc: 0.6652 - auprc: 0.2578 - f1_m: 0.0158 - recall_m: 0.0140 - precision_m: 0.0195 - val_loss: 0.3628 - val_acc: 0.8694 - val_auroc: 0.6656 - val_auprc: 0.2585 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 27/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4189 - acc: 0.8454 - auroc: 0.6660 - auprc: 0.2589 - f1_m: 0.0152 - recall_m: 0.0136 - precision_m: 0.0183 - val_loss: 0.3627 - val_acc: 0.8694 - val_auroc: 0.6665 - val_auprc: 0.2595 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 28/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4182 - acc: 0.8450 - auroc: 0.6671 - auprc: 0.2603 - f1_m: 0.0176 - recall_m: 0.0154 - precision_m: 0.0222 - val_loss: 0.3624 - val_acc: 0.8694 - val_auroc: 0.6674 - val_auprc: 0.2608 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 29/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4183 - acc: 0.8483 - auroc: 0.6678 - auprc: 0.2613 - f1_m: 0.0254 - recall_m: 0.0237 - precision_m: 0.0294 - val_loss: 0.3620 - val_acc: 0.8694 - val_auroc: 0.6682 - val_auprc: 0.2618 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 30/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4178 - acc: 0.8469 - auroc: 0.6688 - auprc: 0.2624 - f1_m: 0.0217 - recall_m: 0.0204 - precision_m: 0.0245 - val_loss: 0.3618 - val_acc: 0.8694 - val_auroc: 0.6690 - val_auprc: 0.2630 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 31/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4161 - acc: 0.8471 - auroc: 0.6697 - auprc: 0.2637 - f1_m: 0.0218 - recall_m: 0.0208 - precision_m: 0.0245 - val_loss: 0.3615 - val_acc: 0.8694 - val_auroc: 0.6699 - val_auprc: 0.2641 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 32/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4166 - acc: 0.8466 - auroc: 0.6705 - auprc: 0.2648 - f1_m: 0.0208 - recall_m: 0.0187 - precision_m: 0.0252 - val_loss: 0.3612 - val_acc: 0.8694 - val_auroc: 0.6708 - val_auprc: 0.2652 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 33/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4203 - acc: 0.8477 - auroc: 0.6710 - auprc: 0.2656 - f1_m: 0.0219 - recall_m: 0.0203 - precision_m: 0.0256 - val_loss: 0.3612 - val_acc: 0.8694 - val_auroc: 0.6712 - val_auprc: 0.2660 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 34/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4157 - acc: 0.8446 - auroc: 0.6716 - auprc: 0.2665 - f1_m: 0.0166 - recall_m: 0.0159 - precision_m: 0.0183 - val_loss: 0.3609 - val_acc: 0.8694 - val_auroc: 0.6720 - val_auprc: 0.2669 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 35/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4159 - acc: 0.8481 - auroc: 0.6723 - auprc: 0.2676 - f1_m: 0.0259 - recall_m: 0.0242 - precision_m: 0.0298 - val_loss: 0.3604 - val_acc: 0.8694 - val_auroc: 0.6727 - val_auprc: 0.2679 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 36/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4156 - acc: 0.8471 - auroc: 0.6731 - auprc: 0.2683 - f1_m: 0.0208 - recall_m: 0.0195 - precision_m: 0.0245 - val_loss: 0.3602 - val_acc: 0.8694 - val_auroc: 0.6733 - val_auprc: 0.2687 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 37/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4182 - acc: 0.8481 - auroc: 0.6735 - auprc: 0.2689 - f1_m: 0.0191 - recall_m: 0.0172 - precision_m: 0.0229 - val_loss: 0.3602 - val_acc: 0.8694 - val_auroc: 0.6739 - val_auprc: 0.2695 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 38/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4156 - acc: 0.8475 - auroc: 0.6743 - auprc: 0.2701 - f1_m: 0.0224 - recall_m: 0.0204 - precision_m: 0.0268 - val_loss: 0.3600 - val_acc: 0.8694 - val_auroc: 0.6745 - val_auprc: 0.2705 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 39/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4178 - acc: 0.8471 - auroc: 0.6749 - auprc: 0.2710 - f1_m: 0.0206 - recall_m: 0.0192 - precision_m: 0.0245 - val_loss: 0.3599 - val_acc: 0.8694 - val_auroc: 0.6749 - val_auprc: 0.2712 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 40/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4181 - acc: 0.8479 - auroc: 0.6752 - auprc: 0.2715 - f1_m: 0.0227 - recall_m: 0.0215 - precision_m: 0.0256 - val_loss: 0.3598 - val_acc: 0.8694 - val_auroc: 0.6754 - val_auprc: 0.2719 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 41/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4134 - acc: 0.8464 - auroc: 0.6759 - auprc: 0.2725 - f1_m: 0.0205 - recall_m: 0.0191 - precision_m: 0.0241 - val_loss: 0.3595 - val_acc: 0.8694 - val_auroc: 0.6761 - val_auprc: 0.2727 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 42/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4153 - acc: 0.8467 - auroc: 0.6763 - auprc: 0.2732 - f1_m: 0.0227 - recall_m: 0.0218 - precision_m: 0.0248 - val_loss: 0.3593 - val_acc: 0.8694 - val_auroc: 0.6766 - val_auprc: 0.2735 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 43/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4160 - acc: 0.8475 - auroc: 0.6771 - auprc: 0.2740 - f1_m: 0.0237 - recall_m: 0.0215 - precision_m: 0.0283 - val_loss: 0.3592 - val_acc: 0.8694 - val_auroc: 0.6772 - val_auprc: 0.2742 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 44/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4129 - acc: 0.8466 - auroc: 0.6775 - auprc: 0.2746 - f1_m: 0.0227 - recall_m: 0.0215 - precision_m: 0.0256 - val_loss: 0.3590 - val_acc: 0.8694 - val_auroc: 0.6778 - val_auprc: 0.2749 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 45/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4144 - acc: 0.8467 - auroc: 0.6781 - auprc: 0.2753 - f1_m: 0.0196 - recall_m: 0.0177 - precision_m: 0.0237 - val_loss: 0.3588 - val_acc: 0.8694 - val_auroc: 0.6782 - val_auprc: 0.2756 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 46/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4150 - acc: 0.8458 - auroc: 0.6784 - auprc: 0.2758 - f1_m: 0.0199 - recall_m: 0.0185 - precision_m: 0.0233 - val_loss: 0.3586 - val_acc: 0.8694 - val_auroc: 0.6786 - val_auprc: 0.2762 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 47/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4129 - acc: 0.8462 - auroc: 0.6788 - auprc: 0.2765 - f1_m: 0.0228 - recall_m: 0.0217 - precision_m: 0.0252 - val_loss: 0.3584 - val_acc: 0.8694 - val_auroc: 0.6791 - val_auprc: 0.2768 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 48/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4127 - acc: 0.8492 - auroc: 0.6793 - auprc: 0.2772 - f1_m: 0.0270 - recall_m: 0.0251 - precision_m: 0.0313 - val_loss: 0.3583 - val_acc: 0.8694 - val_auroc: 0.6796 - val_auprc: 0.2776 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 49/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4131 - acc: 0.8494 - auroc: 0.6798 - auprc: 0.2779 - f1_m: 0.0282 - recall_m: 0.0262 - precision_m: 0.0321 - val_loss: 0.3580 - val_acc: 0.8694 - val_auroc: 0.6800 - val_auprc: 0.2783 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 50/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4134 - acc: 0.8475 - auroc: 0.6803 - auprc: 0.2787 - f1_m: 0.0234 - recall_m: 0.0213 - precision_m: 0.0283 - val_loss: 0.3580 - val_acc: 0.8694 - val_auroc: 0.6804 - val_auprc: 0.2789 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 51/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4152 - acc: 0.8469 - auroc: 0.6806 - auprc: 0.2791 - f1_m: 0.0225 - recall_m: 0.0209 - precision_m: 0.0264 - val_loss: 0.3579 - val_acc: 0.8694 - val_auroc: 0.6807 - val_auprc: 0.2794 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 52/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4152 - acc: 0.8485 - auroc: 0.6809 - auprc: 0.2797 - f1_m: 0.0261 - recall_m: 0.0238 - precision_m: 0.0310 - val_loss: 0.3578 - val_acc: 0.8694 - val_auroc: 0.6811 - val_auprc: 0.2800 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 53/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4099 - acc: 0.8473 - auroc: 0.6814 - auprc: 0.2804 - f1_m: 0.0201 - recall_m: 0.0186 - precision_m: 0.0237 - val_loss: 0.3575 - val_acc: 0.8694 - val_auroc: 0.6816 - val_auprc: 0.2807 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 54/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4130 - acc: 0.8458 - auroc: 0.6818 - auprc: 0.2810 - f1_m: 0.0233 - recall_m: 0.0218 - precision_m: 0.0271 - val_loss: 0.3575 - val_acc: 0.8694 - val_auroc: 0.6820 - val_auprc: 0.2813 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 55/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4118 - acc: 0.8477 - auroc: 0.6822 - auprc: 0.2815 - f1_m: 0.0238 - recall_m: 0.0220 - precision_m: 0.0275 - val_loss: 0.3574 - val_acc: 0.8694 - val_auroc: 0.6824 - val_auprc: 0.2819 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 56/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4112 - acc: 0.8464 - auroc: 0.6826 - auprc: 0.2821 - f1_m: 0.0201 - recall_m: 0.0181 - precision_m: 0.0245 - val_loss: 0.3574 - val_acc: 0.8694 - val_auroc: 0.6828 - val_auprc: 0.2824 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 57/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4160 - acc: 0.8485 - auroc: 0.6829 - auprc: 0.2826 - f1_m: 0.0251 - recall_m: 0.0230 - precision_m: 0.0298 - val_loss: 0.3575 - val_acc: 0.8694 - val_auroc: 0.6830 - val_auprc: 0.2829 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# Epoch 58/100
# 5233/5233 [==============================] - 21s 4ms/step - loss: 0.4131 - acc: 0.8485 - auroc: 0.6831 - auprc: 0.2832 - f1_m: 0.0287 - recall_m: 0.0264 - precision_m: 0.0336 - val_loss: 0.3574 - val_acc: 0.8694 - val_auroc: 0.6833 - val_auprc: 0.2834 - val_f1_m: 0.0137 - val_recall_m: 0.0137 - val_precision_m: 0.0137
# neural tube validation accuracy is: 0.9079965606190885

# %%
# ROC in test set
plt.figure(figsize=(5, 5))
base_fpr = np.linspace(0, 1, 101)
tpr_list = []
auroc_list = []
for i in range(len(Y)):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(Y[i], y_pred_list[i])
    auroc_list.append(sklearn.metrics.roc_auc_score(Y[i], y_pred_list[i]))
    plt.plot(fpr, tpr, 'b', alpha=0.15)
    tpr = np.interp(base_fpr, fpr, tpr)
    tpr[0] = 0.0
    tpr_list.append(tpr)

print(len(tpr_list), len(tpr_list[0]), len(tpr_list[1]))
tpr_list = np.array(tpr_list)
mean_tpr = np.mean(np.array(tpr_list), axis=0)
tpr_std = tpr_list.std(axis=0)

tprs_upper = np.minimum(mean_tpr + 2 * tpr_std, 1)
tprs_lower = mean_tpr - 2 * tpr_std

plt.plot([0, 1], [0, 1], 'k--')
plt.plot(base_fpr, mean_tpr, 'b', label='Keras (area = {:.3f})'.format(np.mean(np.array(auroc_list))))
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.axes().set_aspect('equal', 'datalim')
#plt.savefig(figure_output_name+'.ROC.png')
# Out:
# 6 101 101
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:29: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# PRC in test set
plt.figure(figsize=(5, 5))
base_recall = np.linspace(0, 1, 101)
precision_list = []
auprc_list = []
for i in range(len(Y)):
    recall, precision, thresholds = sklearn.metrics.precision_recall_curve(Y[i], y_pred_list[i])
    auprc_list.append(sklearn.metrics.average_precision_score(Y[i], y_pred_list[i]))
    plt.plot(recall, precision, 'b', alpha=0.15)
    precision = np.interp(base_recall, recall, precision)
    precision[0] = 1.0
    precision_list.append(precision)

print(len(precision_list), len(precision_list[0]), len(precision_list[1]))
precision_list = np.array(precision_list)
mean_precision = np.mean(np.array(precision_list), axis=0)
precision_std = precision_list.std(axis=0)

precisions_upper = np.minimum(mean_precision + 2 * precision_std, 1)
precisions_lower = mean_precision - 2 * precision_std

plt.plot([0, 1], [1, 0], 'k--')
plt.plot(base_recall, mean_precision, 'b', label='Keras (area = {:.3f})'.format(np.mean(np.array(auprc_list))))
plt.fill_between(base_recall, precisions_lower, precisions_upper, color='grey', alpha=0.3)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('PRC curve')
plt.legend(loc='best')
plt.axes().set_aspect('equal', 'datalim')
#plt.savefig(figure_output_name+'.PRC.png')
# Out:
# 6 101 101
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:29: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
for i in range(len(samples)):
    print("validated tissue " + samples[i] + " auROC: " + str(auroc_list[i]))
# Out:
# validated tissue forebrain auROC: 0.715299851663488
# validated tissue heart auROC: 0.7292914979757085
# validated tissue hindbrain auROC: 0.718817667244938
# validated tissue limb auROC: 0.6781861743198437
# validated tissue midbrain auROC: 0.665867340507214
# validated tissue neural tube auROC: 0.6974036522018529

# %%
for i in range(len(samples)):
    print("validated tissue " + samples[i] + " auPRC: " + str(auprc_list[i]))
# Out:
# validated tissue forebrain auPRC: 0.34596635085358773
# validated tissue heart auPRC: 0.30473454656114474
# validated tissue hindbrain auPRC: 0.32167512887790006
# validated tissue limb auPRC: 0.2966129017530563
# validated tissue midbrain auPRC: 0.30728778995383305
# validated tissue neural tube auPRC: 0.22462405290591023

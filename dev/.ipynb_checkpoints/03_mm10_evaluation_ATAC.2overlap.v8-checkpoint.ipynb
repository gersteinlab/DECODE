# %%
#-----import packages-----#

#common python packages
import numpy as np
import string
import random
import os
import pickle
import argparse
import wget
import math
import gc
import matplotlib.pyplot as plt
from datetime import datetime
from tempfile import TemporaryFile

#biological packages
import pybedtools
from pybedtools import featurefuncs
import pyBigWig

#machine learning packages
import sklearn
from sklearn import metrics
from sklearn.utils import shuffle, class_weight
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd

import tensorflow as tf

import keras.backend as K
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Conv2D, MaxPooling2D, BatchNormalization, Flatten, GlobalAveragePooling2D, Multiply
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from keras import backend as K
from keras.engine.topology import Layer, InputSpec
from keras.utils import Sequence, plot_model
from keras.constraints import unit_norm
from keras import regularizers
from keras.callbacks import EarlyStopping, Callback, TensorBoard, ReduceLROnPlateau
import keras_metrics as km
from keras.models import load_model

from models.v8 import create_model
from models.custom_metrics import auroc, auprc, recall_m, precision_m, f1_m

# %matplotlib inline


#notify the OS about GPU
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['KERAS_BACKEND'] = 'tensorflow'
# Out:
# Using TensorFlow backend.

# %%
#parsing command line arguments
# -----parsing command line arguments-----#
parser = argparse.ArgumentParser(description='Training CNN model to predict STARR-seq enhancers based on chromatin accessbility and histone marks')
parser.add_argument('-c', '--cell_types', type=str, help='comma separated string of cell_types')
parser.add_argument('-i', '--in_dir', type=str, help='directory containing 01_data_encoding intermediate tsv files')

#simulate command line input
cmdline_str='-c ' + " HepG2,K562 " + \
    ' -i ' + "/gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/dev/encoded_2overlap/ATAC/"

seq_names = ["ATAC", "H3K27ac", "H3K4me3", "H3K9ac", "H3K4me1"]

#check if the files are there
args = parser.parse_args(cmdline_str.split())
args.cell_types = args.cell_types.split(",")
for cell in args.cell_types:
    for seq in seq_names:
        pos_file = args.in_dir + cell + "." + seq + ".pos.tsv"
        if not os.path.exists(pos_file):
            print(pos_file + " file does not exist")
            exit(1)
        neg_file = args.in_dir + cell + "." + seq + ".neg.tsv"
        if not os.path.exists(neg_file):
            print(neg_file + " file does not exist")
            exit(1)
print("all files found!")
# Out:
# all files found!

# %%
with open(args.in_dir + "hg38_signals.pickle", 'rb') as f:
    X, Y = pickle.load(f)
window_size = int(X.shape[2] * 10)
X = X[:,[1,2,0,3,4],:] # move ATAC-seq to the middle
X, Y = shuffle(X, Y, random_state=0)
x_train = np.expand_dims(X, axis=4)
y_train = Y

#calculate class weights
class_weights = class_weight.compute_class_weight('balanced',
                                                  np.unique(y_train),
                                                  y_train.flatten())
# Out:
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.

# %%
# construct the model
model = create_model(width=int(window_size/10))
es = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
adam = Adam(lr=5e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=9e-5)
model.compile(loss='binary_crossentropy', optimizer=adam, 
    metrics=['accuracy', auroc, auprc, f1_m, recall_m, precision_m])

if os.path.exists('./saved_models/ATAC_hg38.v8.h5'):
    model.load_weights('./saved_models/ATAC_hg38.v8.h5')
else:
    #train the model
    history = model.fit(x_train, y_train,
                        batch_size=32,
                        epochs=100,
                        validation_split=0.1,
                        shuffle=True,
                        class_weight=class_weights,
                        callbacks=[es]) 

    model.save_weights('./saved_models/ATAC_hg38.v8.h5')
# Out:
# /gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/dev/models/v8.py:54: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   model = Model(input=[input_size], output=[pred_output])
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 5, 400, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 5, 400, 128)  6528        input_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            1032        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          1152        dense_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 5, 400, 128)  0           conv2d_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 5, 400, 64)   409664      multiply_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 64)           0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            260         global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           320         dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 5, 400, 64)   0           conv2d_2[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 5, 400, 64)   204864      multiply_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 64)           0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            260         global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           320         dense_5[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 5, 400, 64)   0           conv2d_3[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 391, 128)  409728      multiply_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 128)          0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 8)            1032        global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          1152        dense_7[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 1, 391, 128)  0           conv2d_4[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 1, 195, 128)  0           multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 1, 195, 64)   32832       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 64)           0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 4)            260         global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           320         dense_9[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 1, 195, 64)   0           conv2d_5[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 195, 64)   16448       multiply_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 64)           0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 4)            260         global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 64)           320         dense_11[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 1, 195, 64)   0           conv2d_6[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 195, 128)  32896       multiply_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 128)          0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 8)            1032        global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 128)          1152        dense_13[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 1, 195, 128)  0           conv2d_7[0][0]
#                                                                  dense_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 1, 97, 128)   0           multiply_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 12416)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 256)          3178752     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1)            257         dropout_1[0][0]
# ==================================================================================================
# Total params: 4,300,841
# Trainable params: 4,300,841
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
X[0].shape
# Out:
# (3244, 5, 400, 1)

# %%
with open("./mm10/mm10_all_signals.pickle", 'rb') as f:
    X,Y = pickle.load(f)
samples = ["forebrain", "heart", "hindbrain", "limb", "midbrain", "neural tube"]
for i in range(len(samples)):
    X[i][:, [0, 2], :] = X[i][:, [2, 0], :]

# %%
y_pred_list = []
accuracy_list = []
for i in range(len(samples)):
    y_pred = model.predict(X[i]).ravel()
    y_pred_list.append(y_pred)

    accuracy_s = sklearn.metrics.accuracy_score(Y[i], np.rint(y_pred))
    print(samples[i], "validation accuracy is:", accuracy_s)
    accuracy_list.append(accuracy_s)
# Out:
# forebrain validation accuracy is: 0.7863748458692972
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-9d3c27ce2517> in <module>
#       2 accuracy_list = []
#       3 for i in range(len(samples)):
# ----> 4     y_pred = model.predict(X[i]).ravel()
#       5     y_pred_list.append(y_pred)
#       6
#
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# ROC in test set
ax = plt.figure(figsize=(5, 5))
plt.rcParams["font.size"] = 15
base_fpr = np.linspace(0, 1, 101)
tpr_list = []
auroc_list = []
for i in range(len(Y)):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(Y[i], y_pred_list[i])
    auroc_list.append(sklearn.metrics.roc_auc_score(Y[i], y_pred_list[i]))
    plt.plot(fpr, tpr, 'b', alpha=0.15)
    tpr = np.interp(base_fpr, fpr, tpr)
    tpr[0] = 0.0
    tpr_list.append(tpr)

print(len(tpr_list), len(tpr_list[0]), len(tpr_list[1]))
tpr_list = np.array(tpr_list)
mean_tpr = np.mean(np.array(tpr_list), axis=0)
tpr_std = tpr_list.std(axis=0)

tprs_upper = np.minimum(mean_tpr + 2 * tpr_std, 1)
tprs_lower = mean_tpr - 2 * tpr_std

plt.plot([0, 1], [0, 1], 'k--')
plt.plot(base_fpr, mean_tpr, 'b', label='Keras (area = {:.3f})'.format(np.mean(np.array(auroc_list))))
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.axes().set_aspect('equal', 'datalim')
with open('./output/03_mm10_evaluation_ATAC.2overlap.v8.ROC.pickle','wb') as fid:
    pickle.dump(ax, fid)
#plt.savefig(figure_output_name+'.ROC.png')
# Out:
# 6 101 101
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# PRC in test set
ax = plt.figure(figsize=(5, 5))
plt.rcParams["font.size"] = 15
base_recall = np.linspace(0, 1, 101)
precision_list = []
auprc_list = []
for i in range(len(Y)):
    recall, precision, thresholds = sklearn.metrics.precision_recall_curve(Y[i], y_pred_list[i])
    auprc_list.append(sklearn.metrics.average_precision_score(Y[i], y_pred_list[i]))
    plt.plot(recall, precision, 'b', alpha=0.15)
    precision = np.interp(base_recall, recall, precision)
    precision[0] = 1.0
    precision_list.append(precision)

print(len(precision_list), len(precision_list[0]), len(precision_list[1]))
precision_list = np.array(precision_list)
mean_precision = np.mean(np.array(precision_list), axis=0)
precision_std = precision_list.std(axis=0)

precisions_upper = np.minimum(mean_precision + 2 * precision_std, 1)
precisions_lower = mean_precision - 2 * precision_std

plt.plot([0, 1], [1, 0], 'k--')
plt.plot(base_recall, mean_precision, 'b', label='Keras (area = {:.3f})'.format(np.mean(np.array(auprc_list))))
plt.fill_between(base_recall, precisions_lower, precisions_upper, color='grey', alpha=0.3)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('PRC curve')
plt.legend(loc='best')
plt.axes().set_aspect('equal', 'datalim')
with open('./output/03_mm10_evaluation_ATAC.2overlap.v8.PRC.pickle','wb') as fid:
    pickle.dump(ax, fid)
#plt.savefig(figure_output_name+'.PRC.png')
# Out:
# 6 101 101
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# %matplotlib notebook
# %matplotlib notebook
# with open('./output/03_mm10_evaluation_ATAC.2overlap.v8.PRC.pickle','rb') as fid:
#     ax1 = pickle.load(fid)
# ax1.plot()
# Out:
# <img src="data:image/png;base64,..." width="522.7777916266598">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-298990304e56> in <module>
#       3 with open('./output/03_mm10_evaluation_ATAC.2overlap.v8.PRC.pickle','rb') as fid:
#       4     ax1 = pickle.load(fid)
# ----> 5 ax1.plot()
#
# AttributeError: 'Figure' object has no attribute 'plot'

# %%
for i in range(len(samples)):
    print("validated tissue " + samples[i] + " auROC: " + str(auroc_list[i]))
    
print("\n")

for i in range(len(samples)):
    print("validated tissue " + samples[i] + " auPRC: " + str(auprc_list[i]))
# Out:
# validated tissue forebrain auROC: 0.7371604176021554
# validated tissue heart auROC: 0.7342350983866859
# validated tissue hindbrain auROC: 0.7102372847073665
# validated tissue limb auROC: 0.6741710722677337
# validated tissue midbrain auROC: 0.7509951368165095
# validated tissue neural tube auROC: 0.6996502664636468
#
#
# validated tissue forebrain auPRC: 0.31727992105728337
# validated tissue heart auPRC: 0.1786675298078442
# validated tissue hindbrain auPRC: 0.2649260680214764
# validated tissue limb auPRC: 0.17705828493642786
# validated tissue midbrain auPRC: 0.2975467180152287
# validated tissue neural tube auPRC: 0.16759613307324225

# %%
y_pred_list = []
accuracy_list = []
for i in range(len(samples)):
    
    #fine-tuning
    X_ft = X.copy()
    X_ft.pop(i)
    X_ft = np.array(X_ft)
    X_ft = X_ft.reshape((-1, X_ft.shape[2], X_ft.shape[3], X_ft.shape[4]))
    
    Y_ft = Y.copy()
    Y_ft.pop(i)
    Y_ft = np.array(Y_ft)
    Y_ft = Y_ft.reshape((-1, 1))
    
    X_ft, Y_ft = shuffle(X_ft, Y_ft, random_state=0)
    
    class_weights = class_weight.compute_class_weight('balanced',
                                                  np.unique(Y_ft),
                                                  Y_ft.flatten())
    
    es = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    
    ft_model = create_model(width=int(window_size/10))
    ft_model.load_weights('./saved_models/ATAC_hg38.v8.h5')
    ft_model.compile(loss='binary_crossentropy', 
                     optimizer=Adam(lr=1e-6, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=9e-5), 
                     metrics=['accuracy', auroc, auprc, f1_m, recall_m, precision_m])
    
    #train the model
    history = ft_model.fit(X_ft, Y_ft,
                        batch_size=4,
                        epochs=150,
                        validation_split=0.1,
                        shuffle=True,
                        class_weight=class_weights,
                        callbacks=[es])
    
    y_pred = ft_model.predict(X[i]).ravel()
    y_pred_list.append(y_pred)

    accuracy_s = sklearn.metrics.accuracy_score(Y[i], np.rint(y_pred))
    print(samples[i], "validation accuracy is:", accuracy_s)
    accuracy_list.append(accuracy_s)
# Out:
# /gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/dev/models/v8.py:54: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   model = Model(input=[input_size], output=[pred_output])
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 5, 400, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 5, 400, 128)  6528        input_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            1032        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          1152        dense_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 5, 400, 128)  0           conv2d_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 5, 400, 64)   409664      multiply_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 64)           0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            260         global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           320         dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 5, 400, 64)   0           conv2d_2[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 5, 400, 64)   204864      multiply_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 64)           0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            260         global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           320         dense_5[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 5, 400, 64)   0           conv2d_3[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 391, 128)  409728      multiply_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 128)          0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 8)            1032        global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          1152        dense_7[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 1, 391, 128)  0           conv2d_4[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 1, 195, 128)  0           multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 1, 195, 64)   32832       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 64)           0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 4)            260         global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           320         dense_9[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 1, 195, 64)   0           conv2d_5[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 195, 64)   16448       multiply_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 64)           0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 4)            260         global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 64)           320         dense_11[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 1, 195, 64)   0           conv2d_6[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 195, 128)  32896       multiply_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 128)          0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 8)            1032        global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 128)          1152        dense_13[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 1, 195, 128)  0           conv2d_7[0][0]
#                                                                  dense_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 1, 97, 128)   0           multiply_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 12416)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 256)          3178752     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1)            257         dropout_1[0][0]
# ==================================================================================================
# Total params: 4,300,841
# Trainable params: 4,300,841
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 14598 samples, validate on 1622 samples
# Epoch 1/150
# 14598/14598 [==============================] - 188s 13ms/step - loss: 0.5561 - acc: 0.8211 - auroc: 0.6816 - auprc: 0.2106 - f1_m: 0.0939 - recall_m: 0.0986 - precision_m: 0.0975 - val_loss: 0.3656 - val_acc: 0.8637 - val_auroc: 0.6980 - val_auprc: 0.2101 - val_f1_m: 0.0485 - val_recall_m: 0.0481 - val_precision_m: 0.0518
# Epoch 2/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.3755 - acc: 0.8731 - auroc: 0.7020 - auprc: 0.2099 - f1_m: 0.0355 - recall_m: 0.0345 - precision_m: 0.0390 - val_loss: 0.3141 - val_acc: 0.8896 - val_auroc: 0.7056 - val_auprc: 0.2104 - val_f1_m: 0.0074 - val_recall_m: 0.0074 - val_precision_m: 0.0074
# Epoch 3/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.3371 - acc: 0.8857 - auroc: 0.7096 - auprc: 0.2121 - f1_m: 0.0141 - recall_m: 0.0132 - precision_m: 0.0162 - val_loss: 0.2924 - val_acc: 0.8940 - val_auroc: 0.7143 - val_auprc: 0.2158 - val_f1_m: 0.0049 - val_recall_m: 0.0049 - val_precision_m: 0.0049
# Epoch 4/150
# 14598/14598 [==============================] - 186s 13ms/step - loss: 0.3189 - acc: 0.8880 - auroc: 0.7190 - auprc: 0.2200 - f1_m: 0.0143 - recall_m: 0.0135 - precision_m: 0.0162 - val_loss: 0.2778 - val_acc: 0.8958 - val_auroc: 0.7245 - val_auprc: 0.2249 - val_f1_m: 0.0049 - val_recall_m: 0.0049 - val_precision_m: 0.0049
# Epoch 5/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2974 - acc: 0.8898 - auroc: 0.7399 - auprc: 0.2424 - f1_m: 0.0294 - recall_m: 0.0282 - precision_m: 0.0326 - val_loss: 0.2604 - val_acc: 0.8940 - val_auroc: 0.7448 - val_auprc: 0.2494 - val_f1_m: 0.0152 - val_recall_m: 0.0144 - val_precision_m: 0.0173
# Epoch 7/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2814 - acc: 0.8938 - auroc: 0.7728 - auprc: 0.3015 - f1_m: 0.0692 - recall_m: 0.0671 - precision_m: 0.0750 - val_loss: 0.2475 - val_acc: 0.9001 - val_auroc: 0.7748 - val_auprc: 0.3060 - val_f1_m: 0.0657 - val_recall_m: 0.0658 - val_precision_m: 0.0691
# Epoch 12/150
# 14598/14598 [==============================] - 186s 13ms/step - loss: 0.2763 - acc: 0.8950 - auroc: 0.7880 - auprc: 0.3381 - f1_m: 0.0868 - recall_m: 0.0849 - precision_m: 0.0936 - val_loss: 0.2447 - val_acc: 0.9063 - val_auroc: 0.7892 - val_auprc: 0.3407 - val_f1_m: 0.0895 - val_recall_m: 0.0892 - val_precision_m: 0.0937
# Epoch 17/150
# 14598/14598 [==============================] - 186s 13ms/step - loss: 0.2771 - acc: 0.8935 - auroc: 0.7901 - auprc: 0.3430 - f1_m: 0.0795 - recall_m: 0.0766 - precision_m: 0.0870 - val_loss: 0.2446 - val_acc: 0.9063 - val_auroc: 0.7912 - val_auprc: 0.3452 - val_f1_m: 0.0916 - val_recall_m: 0.0917 - val_precision_m: 0.0949
# Epoch 18/150
# 14598/14598 [==============================] - 186s 13ms/step - loss: 0.2749 - acc: 0.8938 - auroc: 0.8004 - auprc: 0.3682 - f1_m: 0.0837 - recall_m: 0.0815 - precision_m: 0.0908 - val_loss: 0.2432 - val_acc: 0.9051 - val_auroc: 0.8010 - val_auprc: 0.3695 - val_f1_m: 0.0916 - val_recall_m: 0.0917 - val_precision_m: 0.0949
# Epoch 25/150
# 14598/14598 [==============================] - 186s 13ms/step - loss: 0.2753 - acc: 0.8933 - auroc: 0.8015 - auprc: 0.3710 - f1_m: 0.0837 - recall_m: 0.0811 - precision_m: 0.0918 - val_loss: 0.2433 - val_acc: 0.9044 - val_auroc: 0.8019 - val_auprc: 0.3718 - val_f1_m: 0.0916 - val_recall_m: 0.0917 - val_precision_m: 0.0949
# Epoch 26/150
# 14598/14598 [==============================] - 186s 13ms/step - loss: 0.2737 - acc: 0.8931 - auroc: 0.8088 - auprc: 0.3888 - f1_m: 0.0849 - recall_m: 0.0829 - precision_m: 0.0920 - val_loss: 0.2425 - val_acc: 0.9038 - val_auroc: 0.8090 - val_auprc: 0.3894 - val_f1_m: 0.0891 - val_recall_m: 0.0892 - val_precision_m: 0.0925
# Epoch 36/150
# 14598/14598 [==============================] - 186s 13ms/step - loss: 0.2726 - acc: 0.8939 - auroc: 0.8125 - auprc: 0.3977 - f1_m: 0.0849 - recall_m: 0.0827 - precision_m: 0.0916 - val_loss: 0.2421 - val_acc: 0.9038 - val_auroc: 0.8127 - val_auprc: 0.3982 - val_f1_m: 0.0891 - val_recall_m: 0.0892 - val_precision_m: 0.0925
# Epoch 44/150
# 14598/14598 [==============================] - 186s 13ms/step - loss: 0.2711 - acc: 0.8954 - auroc: 0.8152 - auprc: 0.4044 - f1_m: 0.0907 - recall_m: 0.0885 - precision_m: 0.0978 - val_loss: 0.2419 - val_acc: 0.9026 - val_auroc: 0.8153 - val_auprc: 0.4048 - val_f1_m: 0.0908 - val_recall_m: 0.0904 - val_precision_m: 0.0949
# Epoch 52/150
# 14598/14598 [==============================] - 186s 13ms/step - loss: 0.2720 - acc: 0.8947 - auroc: 0.8172 - auprc: 0.4093 - f1_m: 0.0906 - recall_m: 0.0888 - precision_m: 0.0976 - val_loss: 0.2418 - val_acc: 0.9020 - val_auroc: 0.8173 - val_auprc: 0.4095 - val_f1_m: 0.0908 - val_recall_m: 0.0904 - val_precision_m: 0.0949
# Epoch 60/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2955 - acc: 0.8853 - auroc: 0.7863 - auprc: 0.3604 - f1_m: 0.1083 - recall_m: 0.1046 - precision_m: 0.1193 - val_loss: 0.2566 - val_acc: 0.8983 - val_auroc: 0.7881 - val_auprc: 0.3649 - val_f1_m: 0.1068 - val_recall_m: 0.1077 - val_precision_m: 0.1097
# Epoch 13/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2902 - acc: 0.8865 - auroc: 0.8084 - auprc: 0.4186 - f1_m: 0.1185 - recall_m: 0.1170 - precision_m: 0.1261 - val_loss: 0.2534 - val_acc: 0.8989 - val_auroc: 0.8090 - val_auprc: 0.4198 - val_f1_m: 0.1125 - val_recall_m: 0.1126 - val_precision_m: 0.1159
# Epoch 26/150
# 14598/14598 [==============================] - 186s 13ms/step - loss: 0.2888 - acc: 0.8873 - auroc: 0.8128 - auprc: 0.4300 - f1_m: 0.1198 - recall_m: 0.1164 - precision_m: 0.1300 - val_loss: 0.2531 - val_acc: 0.8983 - val_auroc: 0.8131 - val_auprc: 0.4309 - val_f1_m: 0.1175 - val_recall_m: 0.1176 - val_precision_m: 0.1208
# Epoch 32/150
# 14598/14598 [==============================] - 186s 13ms/step - loss: 0.2865 - acc: 0.8861 - auroc: 0.8175 - auprc: 0.4426 - f1_m: 0.1140 - recall_m: 0.1107 - precision_m: 0.1246 - val_loss: 0.2525 - val_acc: 0.8989 - val_auroc: 0.8178 - val_auprc: 0.4432 - val_f1_m: 0.1175 - val_recall_m: 0.1176 - val_precision_m: 0.1208
# Epoch 42/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2879 - acc: 0.8864 - auroc: 0.8202 - auprc: 0.4494 - f1_m: 0.1178 - recall_m: 0.1147 - precision_m: 0.1284 - val_loss: 0.2522 - val_acc: 0.8989 - val_auroc: 0.8203 - val_auprc: 0.4497 - val_f1_m: 0.1175 - val_recall_m: 0.1176 - val_precision_m: 0.1208
# Epoch 50/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2870 - acc: 0.8868 - auroc: 0.8222 - auprc: 0.4541 - f1_m: 0.1213 - recall_m: 0.1188 - precision_m: 0.1306 - val_loss: 0.2520 - val_acc: 0.8989 - val_auroc: 0.8223 - val_auprc: 0.4545 - val_f1_m: 0.1175 - val_recall_m: 0.1176 - val_precision_m: 0.1208
# heart validation accuracy is: 0.9087546239210851
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 5, 400, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 5, 400, 128)  6528        input_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            1032        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          1152        dense_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 5, 400, 128)  0           conv2d_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 5, 400, 64)   409664      multiply_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 64)           0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            260         global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           320         dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 5, 400, 64)   0           conv2d_2[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 5, 400, 64)   204864      multiply_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 64)           0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            260         global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           320         dense_5[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 5, 400, 64)   0           conv2d_3[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 391, 128)  409728      multiply_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 128)          0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 8)            1032        global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          1152        dense_7[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 1, 391, 128)  0           conv2d_4[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 1, 195, 128)  0           multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 1, 195, 64)   32832       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 64)           0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 4)            260         global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           320         dense_9[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 1, 195, 64)   0           conv2d_5[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 195, 64)   16448       multiply_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 64)           0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 4)            260         global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 64)           320         dense_11[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 1, 195, 64)   0           conv2d_6[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 195, 128)  32896       multiply_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 128)          0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 8)            1032        global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 128)          1152        dense_13[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 1, 195, 128)  0           conv2d_7[0][0]
#                                                                  dense_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 1, 97, 128)   0           multiply_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 12416)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 256)          3178752     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1)            257         dropout_1[0][0]
# ==================================================================================================
# Total params: 4,300,841
# Trainable params: 4,300,841
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 14598 samples, validate on 1622 samples
# Epoch 1/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2875 - acc: 0.8894 - auroc: 0.7742 - auprc: 0.3106 - f1_m: 0.0932 - recall_m: 0.0906 - precision_m: 0.1009 - val_loss: 0.2648 - val_acc: 0.8946 - val_auroc: 0.7773 - val_auprc: 0.3173 - val_f1_m: 0.0772 - val_recall_m: 0.0756 - val_precision_m: 0.0814
# Epoch 9/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2782 - acc: 0.8905 - auroc: 0.8036 - auprc: 0.3824 - f1_m: 0.1071 - recall_m: 0.1051 - precision_m: 0.1155 - val_loss: 0.2584 - val_acc: 0.8921 - val_auroc: 0.8047 - val_auprc: 0.3851 - val_f1_m: 0.0936 - val_recall_m: 0.0941 - val_precision_m: 0.0974
# Epoch 17/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2752 - acc: 0.8917 - auroc: 0.8179 - auprc: 0.4183 - f1_m: 0.1122 - recall_m: 0.1096 - precision_m: 0.1204 - val_loss: 0.2561 - val_acc: 0.8933 - val_auroc: 0.8183 - val_auprc: 0.4195 - val_f1_m: 0.1035 - val_recall_m: 0.1040 - val_precision_m: 0.1073
# Epoch 28/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2737 - acc: 0.8915 - auroc: 0.8267 - auprc: 0.4406 - f1_m: 0.1148 - recall_m: 0.1126 - precision_m: 0.1237 - val_loss: 0.2546 - val_acc: 0.8946 - val_auroc: 0.8269 - val_auprc: 0.4411 - val_f1_m: 0.1035 - val_recall_m: 0.1040 - val_precision_m: 0.1073
# Epoch 44/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2727 - acc: 0.8935 - auroc: 0.8294 - auprc: 0.4470 - f1_m: 0.1192 - recall_m: 0.1168 - precision_m: 0.1279 - val_loss: 0.2541 - val_acc: 0.8952 - val_auroc: 0.8295 - val_auprc: 0.4472 - val_f1_m: 0.1060 - val_recall_m: 0.1065 - val_precision_m: 0.1097
# Epoch 52/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2719 - acc: 0.8934 - auroc: 0.8313 - auprc: 0.4517 - f1_m: 0.1198 - recall_m: 0.1175 - precision_m: 0.1280 - val_loss: 0.2538 - val_acc: 0.8964 - val_auroc: 0.8314 - val_auprc: 0.4519 - val_f1_m: 0.1084 - val_recall_m: 0.1089 - val_precision_m: 0.1122
# Epoch 60/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2706 - acc: 0.8927 - auroc: 0.8329 - auprc: 0.4552 - f1_m: 0.1204 - recall_m: 0.1179 - precision_m: 0.1296 - val_loss: 0.2536 - val_acc: 0.8952 - val_auroc: 0.8330 - val_auprc: 0.4554 - val_f1_m: 0.1079 - val_recall_m: 0.1089 - val_precision_m: 0.1114
# Epoch 68/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.3000 - acc: 0.8846 - auroc: 0.7623 - auprc: 0.2915 - f1_m: 0.0695 - recall_m: 0.0663 - precision_m: 0.0778 - val_loss: 0.2852 - val_acc: 0.8890 - val_auroc: 0.7670 - val_auprc: 0.3000 - val_f1_m: 0.0612 - val_recall_m: 0.0588 - val_precision_m: 0.0691
# Epoch 7/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2832 - acc: 0.8887 - auroc: 0.8019 - auprc: 0.3831 - f1_m: 0.1149 - recall_m: 0.1113 - precision_m: 0.1254 - val_loss: 0.2718 - val_acc: 0.8872 - val_auroc: 0.8031 - val_auprc: 0.3858 - val_f1_m: 0.0957 - val_recall_m: 0.0954 - val_precision_m: 0.1011
# Epoch 15/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2818 - acc: 0.8875 - auroc: 0.8147 - auprc: 0.4170 - f1_m: 0.1128 - recall_m: 0.1111 - precision_m: 0.1207 - val_loss: 0.2699 - val_acc: 0.8872 - val_auroc: 0.8152 - val_auprc: 0.4186 - val_f1_m: 0.0982 - val_recall_m: 0.0991 - val_precision_m: 0.1023
# Epoch 23/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2798 - acc: 0.8879 - auroc: 0.8210 - auprc: 0.4343 - f1_m: 0.1207 - recall_m: 0.1175 - precision_m: 0.1307 - val_loss: 0.2684 - val_acc: 0.8878 - val_auroc: 0.8213 - val_auprc: 0.4351 - val_f1_m: 0.0982 - val_recall_m: 0.0991 - val_precision_m: 0.1023
# Epoch 31/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2793 - acc: 0.8889 - auroc: 0.8216 - auprc: 0.4358 - f1_m: 0.1181 - recall_m: 0.1154 - precision_m: 0.1274 - val_loss: 0.2684 - val_acc: 0.8878 - val_auroc: 0.8219 - val_auprc: 0.4367 - val_f1_m: 0.0982 - val_recall_m: 0.0991 - val_precision_m: 0.1023
# Epoch 32/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2774 - acc: 0.8885 - auroc: 0.8287 - auprc: 0.4549 - f1_m: 0.1206 - recall_m: 0.1176 - precision_m: 0.1297 - val_loss: 0.2670 - val_acc: 0.8896 - val_auroc: 0.8289 - val_auprc: 0.4552 - val_f1_m: 0.1006 - val_recall_m: 0.1015 - val_precision_m: 0.1048
# Epoch 50/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2763 - acc: 0.8914 - auroc: 0.7940 - auprc: 0.3613 - f1_m: 0.1021 - recall_m: 0.1000 - precision_m: 0.1092 - val_loss: 0.2719 - val_acc: 0.8927 - val_auroc: 0.7953 - val_auprc: 0.3643 - val_f1_m: 0.0858 - val_recall_m: 0.0855 - val_precision_m: 0.0912
# Epoch 15/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2752 - acc: 0.8931 - auroc: 0.8079 - auprc: 0.3956 - f1_m: 0.1097 - recall_m: 0.1074 - precision_m: 0.1178 - val_loss: 0.2688 - val_acc: 0.8933 - val_auroc: 0.8084 - val_auprc: 0.3969 - val_f1_m: 0.0899 - val_recall_m: 0.0904 - val_precision_m: 0.0949
# Epoch 23/150
# 14598/14598 [==============================] - 191s 13ms/step - loss: 0.2730 - acc: 0.8924 - auroc: 0.8214 - auprc: 0.4279 - f1_m: 0.1123 - recall_m: 0.1097 - precision_m: 0.1210 - val_loss: 0.2651 - val_acc: 0.8946 - val_auroc: 0.8216 - val_auprc: 0.4282 - val_f1_m: 0.0916 - val_recall_m: 0.0917 - val_precision_m: 0.0962
# Epoch 44/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2706 - acc: 0.8938 - auroc: 0.8260 - auprc: 0.4382 - f1_m: 0.1142 - recall_m: 0.1119 - precision_m: 0.1223 - val_loss: 0.2639 - val_acc: 0.8940 - val_auroc: 0.8261 - val_auprc: 0.4384 - val_f1_m: 0.0916 - val_recall_m: 0.0917 - val_precision_m: 0.0962
# Epoch 60/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2701 - acc: 0.8940 - auroc: 0.8281 - auprc: 0.4425 - f1_m: 0.1131 - recall_m: 0.1104 - precision_m: 0.1222 - val_loss: 0.2633 - val_acc: 0.8933 - val_auroc: 0.8282 - val_auprc: 0.4427 - val_f1_m: 0.0916 - val_recall_m: 0.0917 - val_precision_m: 0.0962
# Epoch 71/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2696 - acc: 0.8936 - auroc: 0.8299 - auprc: 0.4467 - f1_m: 0.1150 - recall_m: 0.1132 - precision_m: 0.1234 - val_loss: 0.2629 - val_acc: 0.8933 - val_auroc: 0.8299 - val_auprc: 0.4469 - val_f1_m: 0.0940 - val_recall_m: 0.0941 - val_precision_m: 0.0986
# Epoch 84/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.3070 - acc: 0.8812 - auroc: 0.7570 - auprc: 0.2957 - f1_m: 0.0776 - recall_m: 0.0746 - precision_m: 0.0857 - val_loss: 0.3032 - val_acc: 0.8841 - val_auroc: 0.7616 - val_auprc: 0.3041 - val_f1_m: 0.0740 - val_recall_m: 0.0707 - val_precision_m: 0.0826
# Epoch 7/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2893 - acc: 0.8857 - auroc: 0.7974 - auprc: 0.3873 - f1_m: 0.1201 - recall_m: 0.1167 - precision_m: 0.1316 - val_loss: 0.2907 - val_acc: 0.8872 - val_auroc: 0.7987 - val_auprc: 0.3902 - val_f1_m: 0.1002 - val_recall_m: 0.1011 - val_precision_m: 0.1048
# Epoch 15/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2873 - acc: 0.8851 - auroc: 0.8112 - auprc: 0.4213 - f1_m: 0.1268 - recall_m: 0.1233 - precision_m: 0.1375 - val_loss: 0.2874 - val_acc: 0.8872 - val_auroc: 0.8117 - val_auprc: 0.4227 - val_f1_m: 0.1035 - val_recall_m: 0.1048 - val_precision_m: 0.1073
# Epoch 23/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2855 - acc: 0.8873 - auroc: 0.8183 - auprc: 0.4388 - f1_m: 0.1321 - recall_m: 0.1298 - precision_m: 0.1414 - val_loss: 0.2857 - val_acc: 0.8859 - val_auroc: 0.8186 - val_auprc: 0.4396 - val_f1_m: 0.1084 - val_recall_m: 0.1097 - val_precision_m: 0.1122
# Epoch 31/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2830 - acc: 0.8882 - auroc: 0.8225 - auprc: 0.4491 - f1_m: 0.1372 - recall_m: 0.1335 - precision_m: 0.1489 - val_loss: 0.2845 - val_acc: 0.8866 - val_auroc: 0.8227 - val_auprc: 0.4495 - val_f1_m: 0.1084 - val_recall_m: 0.1097 - val_precision_m: 0.1122
# Epoch 39/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2846 - acc: 0.8864 - auroc: 0.8255 - auprc: 0.4558 - f1_m: 0.1337 - recall_m: 0.1318 - precision_m: 0.1434 - val_loss: 0.2838 - val_acc: 0.8884 - val_auroc: 0.8256 - val_auprc: 0.4561 - val_f1_m: 0.1142 - val_recall_m: 0.1147 - val_precision_m: 0.1184
# Epoch 47/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2837 - acc: 0.8881 - auroc: 0.8284 - auprc: 0.4623 - f1_m: 0.1365 - recall_m: 0.1338 - precision_m: 0.1472 - val_loss: 0.2830 - val_acc: 0.8872 - val_auroc: 0.8285 - val_auprc: 0.4626 - val_f1_m: 0.1142 - val_recall_m: 0.1147 - val_precision_m: 0.1184
# Epoch 58/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2823 - acc: 0.8868 - auroc: 0.8308 - auprc: 0.4678 - f1_m: 0.1345 - recall_m: 0.1325 - precision_m: 0.1439 - val_loss: 0.2823 - val_acc: 0.8878 - val_auroc: 0.8309 - val_auprc: 0.4680 - val_f1_m: 0.1142 - val_recall_m: 0.1147 - val_precision_m: 0.1184
# Epoch 71/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2812 - acc: 0.8855 - auroc: 0.8347 - auprc: 0.4767 - f1_m: 0.1305 - recall_m: 0.1273 - precision_m: 0.1407 - val_loss: 0.2812 - val_acc: 0.8884 - val_auroc: 0.8347 - val_auprc: 0.4768 - val_f1_m: 0.1158 - val_recall_m: 0.1159 - val_precision_m: 0.1208
# Epoch 106/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2817 - acc: 0.8891 - auroc: 0.8353 - auprc: 0.4780 - f1_m: 0.1402 - recall_m: 0.1387 - precision_m: 0.1489 - val_loss: 0.2811 - val_acc: 0.8884 - val_auroc: 0.8353 - val_auprc: 0.4781 - val_f1_m: 0.1158 - val_recall_m: 0.1159 - val_precision_m: 0.1208
# Epoch 114/150
# 14598/14598 [==============================] - 187s 13ms/step - loss: 0.2815 - acc: 0.8877 - auroc: 0.8358 - auprc: 0.4793 - f1_m: 0.1348 - recall_m: 0.1316 - precision_m: 0.1463 - val_loss: 0.2810 - val_acc: 0.8878 - val_auroc: 0.8358 - val_auprc: 0.4793 - val_f1_m: 0.1158 - val_recall_m: 0.1159 - val_precision_m: 0.1208
# Epoch 122/150
# 14598/14598 [==============================] - 188s 13ms/step - loss: 0.2802 - acc: 0.8888 - auroc: 0.8362 - auprc: 0.4802 - f1_m: 0.1368 - recall_m: 0.1333 - precision_m: 0.1475 - val_loss: 0.2808 - val_acc: 0.8884 - val_auroc: 0.8363 - val_auprc: 0.4803 - val_f1_m: 0.1158 - val_recall_m: 0.1159 - val_precision_m: 0.1208
# Epoch 130/150
# 14598/14598 [==============================] - 189s 13ms/step - loss: 0.2811 - acc: 0.8878 - auroc: 0.8371 - auprc: 0.4822 - f1_m: 0.1364 - recall_m: 0.1334 - precision_m: 0.1475 - val_loss: 0.2805 - val_acc: 0.8884 - val_auroc: 0.8371 - val_auprc: 0.4822 - val_f1_m: 0.1158 - val_recall_m: 0.1159 - val_precision_m: 0.1208
# Epoch 146/150
#   952/14598 [>.............................] - ETA: 2:50 - loss: 0.2698 - acc: 0.8887 - auroc: 0.8371 - auprc: 0.4822 - f1_m: 0.1527 - recall_m: 0.1471 - precision_m: 0.1639

# %%
# ROC in test set
ax = plt.figure(figsize=(5, 5))
plt.rcParams["font.size"] = 15
base_fpr = np.linspace(0, 1, 101)
tpr_list = []
auroc_list = []
for i in range(len(Y)):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(Y[i], y_pred_list[i])
    auroc_list.append(sklearn.metrics.roc_auc_score(Y[i], y_pred_list[i]))
    plt.plot(fpr, tpr, 'b', alpha=0.15)
    tpr = np.interp(base_fpr, fpr, tpr)
    tpr[0] = 0.0
    tpr_list.append(tpr)

print(len(tpr_list), len(tpr_list[0]), len(tpr_list[1]))
tpr_list = np.array(tpr_list)
mean_tpr = np.mean(np.array(tpr_list), axis=0)
tpr_std = tpr_list.std(axis=0)

tprs_upper = np.minimum(mean_tpr + 2 * tpr_std, 1)
tprs_lower = mean_tpr - 2 * tpr_std

plt.plot([0, 1], [0, 1], 'k--')
plt.plot(base_fpr, mean_tpr, 'b', label='Keras (area = {:.3f})'.format(np.mean(np.array(auroc_list))))
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.axes().set_aspect('equal', 'datalim')
with open('./output/03_mm10_evaluation_ATAC.2overlap.v8.oos-ROC.pickle','wb') as fid:
    pickle.dump(ax, fid)
#plt.savefig(figure_output_name+'.ROC.png')
# Out:
# 6 101 101
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:29: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# PRC in test set
ax = plt.figure(figsize=(5, 5))
plt.rcParams["font.size"] = 15
base_recall = np.linspace(0, 1, 101)
precision_list = []
auprc_list = []
for i in range(len(Y)):
    recall, precision, thresholds = sklearn.metrics.precision_recall_curve(Y[i], y_pred_list[i])
    auprc_list.append(sklearn.metrics.average_precision_score(Y[i], y_pred_list[i]))
    plt.plot(recall, precision, 'b', alpha=0.15)
    precision = np.interp(base_recall, recall, precision)
    precision[0] = 1.0
    precision_list.append(precision)

print(len(precision_list), len(precision_list[0]), len(precision_list[1]))
precision_list = np.array(precision_list)
mean_precision = np.mean(np.array(precision_list), axis=0)
precision_std = precision_list.std(axis=0)

precisions_upper = np.minimum(mean_precision + 2 * precision_std, 1)
precisions_lower = mean_precision - 2 * precision_std

plt.plot([0, 1], [1, 0], 'k--')
plt.plot(base_recall, mean_precision, 'b', label='Keras (area = {:.3f})'.format(np.mean(np.array(auprc_list))))
plt.fill_between(base_recall, precisions_lower, precisions_upper, color='grey', alpha=0.3)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('PRC curve')
plt.legend(loc='best')
plt.axes().set_aspect('equal', 'datalim')
with open('./output/03_mm10_evaluation_ATAC.2overlap.v8.oos-PRC.pickle','wb') as fid:
    pickle.dump(ax, fid)
#plt.savefig(figure_output_name+'.PRC.png')
# Out:
# 6 101 101
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:29: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
for i in range(len(samples)):
    print("validated tissue " + samples[i] + " auROC: " + str(auroc_list[i]))
print("overall auROC average " + str(np.mean(auroc_list)))
    
print("\n")

for i in range(len(samples)):
    print("validated tissue " + samples[i] + " auPRC: " + str(auprc_list[i]))
print("overall auPRC average " + str(np.mean(auprc_list)))
# Out:
# validated tissue forebrain auROC: 0.8644220784687922
# validated tissue heart auROC: 0.8509172099475958
# validated tissue hindbrain auROC: 0.8168062811968625
# validated tissue limb auROC: 0.8096403283165048
# validated tissue midbrain auROC: 0.8412206116874299
# validated tissue neural tube auROC: 0.8349424248191855
# overall auROC average 0.8363248224060618
#
#
# validated tissue forebrain auPRC: 0.6035807253121017
# validated tissue heart auPRC: 0.42610520766984356
# validated tissue hindbrain auPRC: 0.4574230490045541
# validated tissue limb auPRC: 0.3975440271060617
# validated tissue midbrain auPRC: 0.5258841563126523
# validated tissue neural tube auPRC: 0.39989823084870485
# overall auPRC average 0.468405899375653

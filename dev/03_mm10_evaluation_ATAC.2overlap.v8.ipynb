# %%
#-----import packages-----#

#common python packages
import numpy as np
import string
import random
import os
import pickle
import argparse
import wget
import math
import gc
import matplotlib.pyplot as plt
from datetime import datetime
from tempfile import TemporaryFile

#biological packages
import pybedtools
from pybedtools import featurefuncs
import pyBigWig

#machine learning packages
import sklearn
from sklearn import metrics
from sklearn.utils import shuffle, class_weight
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd

import tensorflow as tf

import keras.backend as K
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Conv2D, MaxPooling2D, BatchNormalization, Flatten, GlobalAveragePooling2D, Multiply
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from keras import backend as K
from keras.engine.topology import Layer, InputSpec
from keras.utils import Sequence, plot_model
from keras.constraints import unit_norm
from keras import regularizers
from keras.callbacks import EarlyStopping, Callback, TensorBoard, ReduceLROnPlateau
import keras_metrics as km
from keras.models import load_model

from models.v8 import create_model
from models.custom_metrics import auroc, auprc, recall_m, precision_m, f1_m

# %matplotlib inline


#notify the OS about GPU
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['KERAS_BACKEND'] = 'tensorflow'
# Out:
# Using TensorFlow backend.

# %%
#parsing command line arguments
# -----parsing command line arguments-----#
parser = argparse.ArgumentParser(description='Training CNN model to predict STARR-seq enhancers based on chromatin accessbility and histone marks')
parser.add_argument('-c', '--cell_types', type=str, help='comma separated string of cell_types')
parser.add_argument('-i', '--in_dir', type=str, help='directory containing 01_data_encoding intermediate tsv files')

#simulate command line input
cmdline_str='-c ' + " HepG2,K562 " + \
    ' -i ' + "/gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/dev/encoded_2overlap/ATAC/"

seq_names = ["ATAC", "H3K27ac", "H3K4me3", "H3K9ac", "H3K4me1"]

#check if the files are there
args = parser.parse_args(cmdline_str.split())
args.cell_types = args.cell_types.split(",")
for cell in args.cell_types:
    for seq in seq_names:
        pos_file = args.in_dir + cell + "." + seq + ".pos.tsv"
        if not os.path.exists(pos_file):
            print(pos_file + " file does not exist")
            exit(1)
        neg_file = args.in_dir + cell + "." + seq + ".neg.tsv"
        if not os.path.exists(neg_file):
            print(neg_file + " file does not exist")
            exit(1)
print("all files found!")
# Out:
# all files found!

# %%
with open(args.in_dir + "hg38_signals.pickle", 'rb') as f:
    X, Y = pickle.load(f)
window_size = int(X.shape[2] * 10)
X = X[:,[1,2,0,3,4],:] # move ATAC-seq to the middle
X, Y = shuffle(X, Y, random_state=0)
x_train = np.expand_dims(X, axis=4)
y_train = Y

#calculate class weights
class_weights = class_weight.compute_class_weight('balanced',
                                                  np.unique(y_train),
                                                  y_train.flatten())
# Out:
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.

# %%
# construct the model
model = create_model(width=int(window_size/10))
es = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
adam = Adam(lr=5e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=9e-5)
model.compile(loss='binary_crossentropy', optimizer=adam, 
    metrics=['accuracy', auroc, auprc, f1_m, recall_m, precision_m])

if os.path.exists('./saved_models/ATAC_hg38.v8.h5'):
    model.load_weights('./saved_models/ATAC_hg38.v8.h5')
else:
    #train the model
    history = model.fit(x_train, y_train,
                        batch_size=32,
                        epochs=100,
                        validation_split=0.1,
                        shuffle=True,
                        class_weight=class_weights,
                        callbacks=[es]) 

    model.save_weights('./saved_models/ATAC_hg38.v8.h5')
# Out:
# /gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/dev/models/v8.py:54: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   model = Model(input=[input_size], output=[pred_output])
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 5, 400, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 5, 400, 128)  6528        input_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            1032        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          1152        dense_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 5, 400, 128)  0           conv2d_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 5, 400, 64)   409664      multiply_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 64)           0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            260         global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           320         dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 5, 400, 64)   0           conv2d_2[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 5, 400, 64)   204864      multiply_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 64)           0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            260         global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           320         dense_5[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 5, 400, 64)   0           conv2d_3[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 391, 128)  409728      multiply_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 128)          0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 8)            1032        global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          1152        dense_7[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 1, 391, 128)  0           conv2d_4[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 1, 195, 128)  0           multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 1, 195, 64)   32832       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 64)           0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 4)            260         global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           320         dense_9[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 1, 195, 64)   0           conv2d_5[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 195, 64)   16448       multiply_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 64)           0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 4)            260         global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 64)           320         dense_11[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 1, 195, 64)   0           conv2d_6[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 195, 128)  32896       multiply_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 128)          0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 8)            1032        global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 128)          1152        dense_13[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 1, 195, 128)  0           conv2d_7[0][0]
#                                                                  dense_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 1, 97, 128)   0           multiply_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 12416)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 256)          3178752     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1)            257         dropout_1[0][0]
# ==================================================================================================
# Total params: 4,300,841
# Trainable params: 4,300,841
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
with open("./mm10/mm10_all_signals.pickle", 'rb') as f:
    X,Y = pickle.load(f)
samples = ["forebrain", "heart", "hindbrain", "limb", "midbrain", "neural tube"]
for i in range(len(samples)):
    X[i][:, [0, 2], :] = X[i][:, [2, 0], :]

# %%
y_pred_list = []
accuracy_list = []
for i in range(len(samples)):
    y_pred = model.predict(X[i]).ravel()
    y_pred_list.append(y_pred)

    accuracy_s = sklearn.metrics.accuracy_score(Y[i], np.rint(y_pred))
    print(samples[i], "validation accuracy is:", accuracy_s)
    accuracy_list.append(accuracy_s)
# Out:
# forebrain validation accuracy is: 0.7863748458692972
# heart validation accuracy is: 0.8363131935881628
# hindbrain validation accuracy is: 0.8024044389642416
# limb validation accuracy is: 0.8159679408138101
# midbrain validation accuracy is: 0.7987053020961775
# neural tube validation accuracy is: 0.8147348951911221

# %%
# ROC in test set
ax = plt.figure(figsize=(5, 5))
plt.rcParams["font.size"] = 15
base_fpr = np.linspace(0, 1, 101)
tpr_list = []
auroc_list = []
for i in range(len(Y)):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(Y[i], y_pred_list[i])
    auroc_list.append(sklearn.metrics.roc_auc_score(Y[i], y_pred_list[i]))
    plt.plot(fpr, tpr, 'b', alpha=0.15)
    tpr = np.interp(base_fpr, fpr, tpr)
    tpr[0] = 0.0
    tpr_list.append(tpr)

print(len(tpr_list), len(tpr_list[0]), len(tpr_list[1]))
tpr_list = np.array(tpr_list)
mean_tpr = np.mean(np.array(tpr_list), axis=0)
tpr_std = tpr_list.std(axis=0)

tprs_upper = np.minimum(mean_tpr + 2 * tpr_std, 1)
tprs_lower = mean_tpr - 2 * tpr_std

plt.plot([0, 1], [0, 1], 'k--')
plt.plot(base_fpr, mean_tpr, 'b', label='Keras (area = {:.3f})'.format(np.mean(np.array(auroc_list))))
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.axes().set_aspect('equal', 'datalim')
with open('./output/03_mm10_evaluation_ATAC.2overlap.v8.ROC.pickle','wb') as fid:
    pickle.dump(ax, fid)
#plt.savefig(figure_output_name+'.ROC.png')
# Out:
# 6 101 101
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# PRC in test set
ax = plt.figure(figsize=(5, 5))
plt.rcParams["font.size"] = 15
base_recall = np.linspace(0, 1, 101)
precision_list = []
auprc_list = []
for i in range(len(Y)):
    recall, precision, thresholds = sklearn.metrics.precision_recall_curve(Y[i], y_pred_list[i])
    auprc_list.append(sklearn.metrics.average_precision_score(Y[i], y_pred_list[i]))
    plt.plot(recall, precision, 'b', alpha=0.15)
    precision = np.interp(base_recall, recall, precision)
    precision[0] = 1.0
    precision_list.append(precision)

print(len(precision_list), len(precision_list[0]), len(precision_list[1]))
precision_list = np.array(precision_list)
mean_precision = np.mean(np.array(precision_list), axis=0)
precision_std = precision_list.std(axis=0)

precisions_upper = np.minimum(mean_precision + 2 * precision_std, 1)
precisions_lower = mean_precision - 2 * precision_std

plt.plot([0, 1], [1, 0], 'k--')
plt.plot(base_recall, mean_precision, 'b', label='Keras (area = {:.3f})'.format(np.mean(np.array(auprc_list))))
plt.fill_between(base_recall, precisions_lower, precisions_upper, color='grey', alpha=0.3)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('PRC curve')
plt.legend(loc='best')
plt.axes().set_aspect('equal', 'datalim')
with open('./output/03_mm10_evaluation_ATAC.2overlap.v8.PRC.pickle','wb') as fid:
    pickle.dump(ax, fid)
#plt.savefig(figure_output_name+'.PRC.png')
# Out:
# 6 101 101
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# %matplotlib notebook
# %matplotlib notebook
# with open('./output/03_mm10_evaluation_ATAC.2overlap.v8.PRC.pickle','rb') as fid:
#     ax1 = pickle.load(fid)
# ax1.plot()

# %%
for i in range(len(samples)):
    print("validated tissue " + samples[i] + " auROC: " + str(auroc_list[i]))
    
print("\n")

for i in range(len(samples)):
    print("validated tissue " + samples[i] + " auPRC: " + str(auprc_list[i]))
# Out:
# validated tissue forebrain auROC: 0.7847103726986978
# validated tissue heart auROC: 0.7904122431947629
# validated tissue hindbrain auROC: 0.7656344276232789
# validated tissue limb auROC: 0.7433935829046803
# validated tissue midbrain auROC: 0.7861486113084806
# validated tissue neural tube auROC: 0.7646816711077273
#
#
# validated tissue forebrain auPRC: 0.3236096095768341
# validated tissue heart auPRC: 0.21912886460442124
# validated tissue hindbrain auPRC: 0.2752375753072359
# validated tissue limb auPRC: 0.20572794674138928
# validated tissue midbrain auPRC: 0.2996186265553615
# validated tissue neural tube auPRC: 0.1901301342268586

# %%
y_pred_list = []
accuracy_list = []
for i in range(len(samples)):
    
    #fine-tuning
    X_ft = X.copy()
    X_ft.pop(i)
    X_ft = np.array(X_ft)
    X_ft = X_ft.reshape((-1, X_ft.shape[2], X_ft.shape[3], X_ft.shape[4]))
    
    Y_ft = Y.copy()
    Y_ft.pop(i)
    Y_ft = np.array(Y_ft)
    Y_ft = Y_ft.reshape((-1, 1))
    
    X_ft, Y_ft = shuffle(X_ft, Y_ft, random_state=0)
    
    class_weights = class_weight.compute_class_weight('balanced',
                                                  np.unique(Y_ft),
                                                  Y_ft.flatten())
    
    es = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    
    ft_model = create_model(width=int(window_size/10))
    ft_model.load_weights('./saved_models/ATAC_hg38.v8.h5')
    ft_model.compile(loss='binary_crossentropy', 
                     optimizer=Adam(lr=1e-6, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=9e-5), 
                     metrics=['accuracy', auroc, auprc, f1_m, recall_m, precision_m])
    
    #train the model
    history = ft_model.fit(X_ft, Y_ft,
                        batch_size=4,
                        epochs=150,
                        validation_split=0.1,
                        shuffle=True,
                        class_weight=class_weights,
                        callbacks=[es])
    
    y_pred = ft_model.predict(X[i]).ravel()
    y_pred_list.append(y_pred)

    accuracy_s = sklearn.metrics.accuracy_score(Y[i], np.rint(y_pred))
    print(samples[i], "validation accuracy is:", accuracy_s)
    accuracy_list.append(accuracy_s)
# Out:
# /gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/dev/models/v8.py:54: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   model = Model(input=[input_size], output=[pred_output])
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 5, 400, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 5, 400, 128)  6528        input_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            1032        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          1152        dense_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 5, 400, 128)  0           conv2d_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 5, 400, 64)   409664      multiply_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 64)           0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            260         global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           320         dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 5, 400, 64)   0           conv2d_2[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 5, 400, 64)   204864      multiply_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 64)           0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            260         global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           320         dense_5[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 5, 400, 64)   0           conv2d_3[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 391, 128)  409728      multiply_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 128)          0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 8)            1032        global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          1152        dense_7[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 1, 391, 128)  0           conv2d_4[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 1, 195, 128)  0           multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 1, 195, 64)   32832       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 64)           0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 4)            260         global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           320         dense_9[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 1, 195, 64)   0           conv2d_5[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 195, 64)   16448       multiply_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 64)           0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 4)            260         global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 64)           320         dense_11[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 1, 195, 64)   0           conv2d_6[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 195, 128)  32896       multiply_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 128)          0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 8)            1032        global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 128)          1152        dense_13[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 1, 195, 128)  0           conv2d_7[0][0]
#                                                                  dense_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 1, 97, 128)   0           multiply_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 12416)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 256)          3178752     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1)            257         dropout_1[0][0]
# ==================================================================================================
# Total params: 4,300,841
# Trainable params: 4,300,841
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 14598 samples, validate on 1622 samples
# Epoch 1/150
# 14598/14598 [==============================] - 192s 13ms/step - loss: 0.4405 - acc: 0.8332 - auroc: 0.7486 - auprc: 0.2201 - f1_m: 0.0672 - recall_m: 0.0707 - precision_m: 0.0701 - val_loss: 0.3302 - val_acc: 0.8822 - val_auroc: 0.7408 - val_auprc: 0.2142 - val_f1_m: 0.0066 - val_recall_m: 0.0062 - val_precision_m: 0.0074
# Epoch 2/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.3252 - acc: 0.8866 - auroc: 0.7394 - auprc: 0.2120 - f1_m: 0.0011 - recall_m: 9.5904e-04 - precision_m: 0.0014 - val_loss: 0.2869 - val_acc: 0.8958 - val_auroc: 0.7429 - val_auprc: 0.2154 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 4/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.3127 - acc: 0.8868 - auroc: 0.7472 - auprc: 0.2197 - f1_m: 0.0010 - recall_m: 9.5904e-04 - precision_m: 0.0011 - val_loss: 0.2777 - val_acc: 0.8964 - val_auroc: 0.7508 - val_auprc: 0.2232 - val_f1_m: 0.0000e+00 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00
# Epoch 5/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2818 - acc: 0.8925 - auroc: 0.7915 - auprc: 0.2993 - f1_m: 0.0403 - recall_m: 0.0381 - precision_m: 0.0452 - val_loss: 0.2514 - val_acc: 0.8995 - val_auroc: 0.7926 - val_auprc: 0.3028 - val_f1_m: 0.0353 - val_recall_m: 0.0345 - val_precision_m: 0.0382
# Epoch 14/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2753 - acc: 0.8942 - auroc: 0.8074 - auprc: 0.3536 - f1_m: 0.0707 - recall_m: 0.0690 - precision_m: 0.0762 - val_loss: 0.2467 - val_acc: 0.8995 - val_auroc: 0.8079 - val_auprc: 0.3553 - val_f1_m: 0.0674 - val_recall_m: 0.0666 - val_precision_m: 0.0715
# Epoch 25/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2729 - acc: 0.8949 - auroc: 0.8139 - auprc: 0.3773 - f1_m: 0.0764 - recall_m: 0.0734 - precision_m: 0.0838 - val_loss: 0.2454 - val_acc: 0.9001 - val_auroc: 0.8140 - val_auprc: 0.3782 - val_f1_m: 0.0855 - val_recall_m: 0.0838 - val_precision_m: 0.0912
# Epoch 35/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2709 - acc: 0.8957 - auroc: 0.8169 - auprc: 0.3892 - f1_m: 0.0854 - recall_m: 0.0835 - precision_m: 0.0912 - val_loss: 0.2446 - val_acc: 0.9001 - val_auroc: 0.8171 - val_auprc: 0.3897 - val_f1_m: 0.0855 - val_recall_m: 0.0838 - val_precision_m: 0.0912
# Epoch 43/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.3133 - acc: 0.8753 - auroc: 0.7709 - auprc: 0.2745 - f1_m: 0.0208 - recall_m: 0.0193 - precision_m: 0.0241 - val_loss: 0.2739 - val_acc: 0.8884 - val_auroc: 0.7740 - val_auprc: 0.2803 - val_f1_m: 0.0164 - val_recall_m: 0.0160 - val_precision_m: 0.0185
# Epoch 8/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2994 - acc: 0.8803 - auroc: 0.7985 - auprc: 0.3428 - f1_m: 0.0709 - recall_m: 0.0675 - precision_m: 0.0793 - val_loss: 0.2621 - val_acc: 0.8903 - val_auroc: 0.7995 - val_auprc: 0.3460 - val_f1_m: 0.0666 - val_recall_m: 0.0654 - val_precision_m: 0.0703
# Epoch 16/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2913 - acc: 0.8853 - auroc: 0.8136 - auprc: 0.3968 - f1_m: 0.1002 - recall_m: 0.0963 - precision_m: 0.1106 - val_loss: 0.2567 - val_acc: 0.8952 - val_auroc: 0.8139 - val_auprc: 0.3980 - val_f1_m: 0.0978 - val_recall_m: 0.0949 - val_precision_m: 0.1048
# Epoch 29/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2895 - acc: 0.8859 - auroc: 0.8181 - auprc: 0.4133 - f1_m: 0.1044 - recall_m: 0.1013 - precision_m: 0.1142 - val_loss: 0.2557 - val_acc: 0.8946 - val_auroc: 0.8183 - val_auprc: 0.4141 - val_f1_m: 0.1065 - val_recall_m: 0.1036 - val_precision_m: 0.1134
# Epoch 37/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.3033 - acc: 0.8799 - auroc: 0.7708 - auprc: 0.2549 - f1_m: 0.0077 - recall_m: 0.0073 - precision_m: 0.0085 - val_loss: 0.2719 - val_acc: 0.8927 - val_auroc: 0.7744 - val_auprc: 0.2607 - val_f1_m: 0.0127 - val_recall_m: 0.0119 - val_precision_m: 0.0148
# Epoch 7/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2758 - acc: 0.8907 - auroc: 0.8217 - auprc: 0.3972 - f1_m: 0.1003 - recall_m: 0.0978 - precision_m: 0.1091 - val_loss: 0.2526 - val_acc: 0.8977 - val_auroc: 0.8221 - val_auprc: 0.3987 - val_f1_m: 0.1052 - val_recall_m: 0.1032 - val_precision_m: 0.1122
# Epoch 28/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2738 - acc: 0.8923 - auroc: 0.8264 - auprc: 0.4152 - f1_m: 0.1086 - recall_m: 0.1058 - precision_m: 0.1169 - val_loss: 0.2518 - val_acc: 0.9001 - val_auroc: 0.8267 - val_auprc: 0.4162 - val_f1_m: 0.1134 - val_recall_m: 0.1102 - val_precision_m: 0.1221
# Epoch 36/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2710 - acc: 0.8932 - auroc: 0.8331 - auprc: 0.4400 - f1_m: 0.1157 - recall_m: 0.1128 - precision_m: 0.1243 - val_loss: 0.2506 - val_acc: 0.9014 - val_auroc: 0.8333 - val_auprc: 0.4405 - val_f1_m: 0.1228 - val_recall_m: 0.1212 - val_precision_m: 0.1295
# Epoch 57/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2708 - acc: 0.8938 - auroc: 0.8347 - auprc: 0.4458 - f1_m: 0.1185 - recall_m: 0.1151 - precision_m: 0.1281 - val_loss: 0.2503 - val_acc: 0.9001 - val_auroc: 0.8348 - val_auprc: 0.4460 - val_f1_m: 0.1212 - val_recall_m: 0.1200 - val_precision_m: 0.1270
# Epoch 65/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2705 - acc: 0.8946 - auroc: 0.8374 - auprc: 0.4555 - f1_m: 0.1213 - recall_m: 0.1182 - precision_m: 0.1314 - val_loss: 0.2499 - val_acc: 0.9001 - val_auroc: 0.8375 - val_auprc: 0.4557 - val_f1_m: 0.1212 - val_recall_m: 0.1200 - val_precision_m: 0.1270
# Epoch 86/150
# 14598/14598 [==============================] - 191s 13ms/step - loss: 0.2941 - acc: 0.8816 - auroc: 0.7954 - auprc: 0.3116 - f1_m: 0.0538 - recall_m: 0.0517 - precision_m: 0.0586 - val_loss: 0.2715 - val_acc: 0.8927 - val_auroc: 0.7974 - val_auprc: 0.3164 - val_f1_m: 0.0575 - val_recall_m: 0.0551 - val_precision_m: 0.0629
# Epoch 11/150
# 14598/14598 [==============================] - 191s 13ms/step - loss: 0.2845 - acc: 0.8859 - auroc: 0.8136 - auprc: 0.3708 - f1_m: 0.0902 - recall_m: 0.0875 - precision_m: 0.0981 - val_loss: 0.2657 - val_acc: 0.8903 - val_auroc: 0.8143 - val_auprc: 0.3732 - val_f1_m: 0.0847 - val_recall_m: 0.0834 - val_precision_m: 0.0900
# Epoch 19/150
# 14598/14598 [==============================] - 191s 13ms/step - loss: 0.2789 - acc: 0.8886 - auroc: 0.8285 - auprc: 0.4286 - f1_m: 0.1158 - recall_m: 0.1128 - precision_m: 0.1251 - val_loss: 0.2628 - val_acc: 0.8921 - val_auroc: 0.8288 - val_auprc: 0.4293 - val_f1_m: 0.1027 - val_recall_m: 0.1015 - val_precision_m: 0.1085
# Epoch 40/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2783 - acc: 0.8891 - auroc: 0.8338 - auprc: 0.4484 - f1_m: 0.1208 - recall_m: 0.1187 - precision_m: 0.1303 - val_loss: 0.2623 - val_acc: 0.8933 - val_auroc: 0.8339 - val_auprc: 0.4487 - val_f1_m: 0.1125 - val_recall_m: 0.1114 - val_precision_m: 0.1196
# Epoch 61/150
# 14598/14598 [==============================] - 192s 13ms/step - loss: 0.4435 - acc: 0.8276 - auroc: 0.7583 - auprc: 0.2481 - f1_m: 0.0780 - recall_m: 0.0846 - precision_m: 0.0791 - val_loss: 0.3545 - val_acc: 0.8810 - val_auroc: 0.7418 - val_auprc: 0.2236 - val_f1_m: 0.0156 - val_recall_m: 0.0148 - val_precision_m: 0.0173
# Epoch 2/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2897 - acc: 0.8848 - auroc: 0.7843 - auprc: 0.2836 - f1_m: 0.0375 - recall_m: 0.0357 - precision_m: 0.0422 - val_loss: 0.2729 - val_acc: 0.8977 - val_auroc: 0.7867 - val_auprc: 0.2891 - val_f1_m: 0.0415 - val_recall_m: 0.0390 - val_precision_m: 0.0469
# Epoch 10/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2733 - acc: 0.8923 - auroc: 0.8199 - auprc: 0.3920 - f1_m: 0.1013 - recall_m: 0.0987 - precision_m: 0.1093 - val_loss: 0.2642 - val_acc: 0.8940 - val_auroc: 0.8203 - val_auprc: 0.3934 - val_f1_m: 0.0855 - val_recall_m: 0.0834 - val_precision_m: 0.0925
# Epoch 31/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2717 - acc: 0.8935 - auroc: 0.8279 - auprc: 0.4201 - f1_m: 0.1091 - recall_m: 0.1067 - precision_m: 0.1172 - val_loss: 0.2621 - val_acc: 0.8921 - val_auroc: 0.8280 - val_auprc: 0.4204 - val_f1_m: 0.0855 - val_recall_m: 0.0847 - val_precision_m: 0.0912
# Epoch 52/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2701 - acc: 0.8951 - auroc: 0.8316 - auprc: 0.4326 - f1_m: 0.1145 - recall_m: 0.1127 - precision_m: 0.1222 - val_loss: 0.2608 - val_acc: 0.8933 - val_auroc: 0.8316 - val_auprc: 0.4329 - val_f1_m: 0.0921 - val_recall_m: 0.0908 - val_precision_m: 0.0986
# Epoch 73/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2689 - acc: 0.8933 - auroc: 0.8326 - auprc: 0.4359 - f1_m: 0.1117 - recall_m: 0.1095 - precision_m: 0.1212 - val_loss: 0.2605 - val_acc: 0.8933 - val_auroc: 0.8327 - val_auprc: 0.4360 - val_f1_m: 0.0921 - val_recall_m: 0.0908 - val_precision_m: 0.0986
# Epoch 81/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2690 - acc: 0.8936 - auroc: 0.8339 - auprc: 0.4402 - f1_m: 0.1122 - recall_m: 0.1099 - precision_m: 0.1198 - val_loss: 0.2600 - val_acc: 0.8940 - val_auroc: 0.8339 - val_auprc: 0.4403 - val_f1_m: 0.0954 - val_recall_m: 0.0945 - val_precision_m: 0.1011
# Epoch 94/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2684 - acc: 0.8941 - auroc: 0.8345 - auprc: 0.4423 - f1_m: 0.1125 - recall_m: 0.1105 - precision_m: 0.1216 - val_loss: 0.2597 - val_acc: 0.8933 - val_auroc: 0.8345 - val_auprc: 0.4424 - val_f1_m: 0.0937 - val_recall_m: 0.0933 - val_precision_m: 0.0986
# Epoch 102/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2686 - acc: 0.8942 - auroc: 0.8359 - auprc: 0.4466 - f1_m: 0.1123 - recall_m: 0.1098 - precision_m: 0.1209 - val_loss: 0.2591 - val_acc: 0.8940 - val_auroc: 0.8359 - val_auprc: 0.4467 - val_f1_m: 0.0954 - val_recall_m: 0.0945 - val_precision_m: 0.1011
# Epoch 123/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2676 - acc: 0.8942 - auroc: 0.8369 - auprc: 0.4498 - f1_m: 0.1150 - recall_m: 0.1114 - precision_m: 0.1247 - val_loss: 0.2587 - val_acc: 0.8921 - val_auroc: 0.8370 - val_auprc: 0.4499 - val_f1_m: 0.0954 - val_recall_m: 0.0945 - val_precision_m: 0.1011
# Epoch 144/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2932 - acc: 0.8831 - auroc: 0.8060 - auprc: 0.3574 - f1_m: 0.0943 - recall_m: 0.0907 - precision_m: 0.1047 - val_loss: 0.2897 - val_acc: 0.8841 - val_auroc: 0.8071 - val_auprc: 0.3610 - val_f1_m: 0.0822 - val_recall_m: 0.0806 - val_precision_m: 0.0900
# Epoch 15/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2875 - acc: 0.8860 - auroc: 0.8177 - auprc: 0.3996 - f1_m: 0.1151 - recall_m: 0.1133 - precision_m: 0.1232 - val_loss: 0.2857 - val_acc: 0.8847 - val_auroc: 0.8182 - val_auprc: 0.4013 - val_f1_m: 0.0986 - val_recall_m: 0.0966 - val_precision_m: 0.1073
# Epoch 23/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2824 - acc: 0.8877 - auroc: 0.8293 - auprc: 0.4418 - f1_m: 0.1292 - recall_m: 0.1265 - precision_m: 0.1400 - val_loss: 0.2818 - val_acc: 0.8884 - val_auroc: 0.8295 - val_auprc: 0.4424 - val_f1_m: 0.1085 - val_recall_m: 0.1077 - val_precision_m: 0.1159
# Epoch 44/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2836 - acc: 0.8875 - auroc: 0.8314 - auprc: 0.4496 - f1_m: 0.1269 - recall_m: 0.1242 - precision_m: 0.1374 - val_loss: 0.2811 - val_acc: 0.8884 - val_auroc: 0.8315 - val_auprc: 0.4501 - val_f1_m: 0.1101 - val_recall_m: 0.1097 - val_precision_m: 0.1159
# Epoch 52/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2819 - acc: 0.8881 - auroc: 0.8349 - auprc: 0.4624 - f1_m: 0.1336 - recall_m: 0.1312 - precision_m: 0.1443 - val_loss: 0.2798 - val_acc: 0.8890 - val_auroc: 0.8350 - val_auprc: 0.4627 - val_f1_m: 0.1109 - val_recall_m: 0.1110 - val_precision_m: 0.1159
# Epoch 73/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2816 - acc: 0.8879 - auroc: 0.8359 - auprc: 0.4656 - f1_m: 0.1322 - recall_m: 0.1290 - precision_m: 0.1435 - val_loss: 0.2794 - val_acc: 0.8884 - val_auroc: 0.8359 - val_auprc: 0.4659 - val_f1_m: 0.1109 - val_recall_m: 0.1110 - val_precision_m: 0.1159
# Epoch 81/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2788 - acc: 0.8890 - auroc: 0.8378 - auprc: 0.4720 - f1_m: 0.1393 - recall_m: 0.1364 - precision_m: 0.1503 - val_loss: 0.2786 - val_acc: 0.8872 - val_auroc: 0.8378 - val_auprc: 0.4721 - val_f1_m: 0.1109 - val_recall_m: 0.1110 - val_precision_m: 0.1159
# Epoch 102/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2783 - acc: 0.8892 - auroc: 0.8383 - auprc: 0.4739 - f1_m: 0.1361 - recall_m: 0.1334 - precision_m: 0.1469 - val_loss: 0.2784 - val_acc: 0.8878 - val_auroc: 0.8384 - val_auprc: 0.4740 - val_f1_m: 0.1109 - val_recall_m: 0.1110 - val_precision_m: 0.1159
# Epoch 110/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2786 - acc: 0.8881 - auroc: 0.8395 - auprc: 0.4778 - f1_m: 0.1373 - recall_m: 0.1359 - precision_m: 0.1464 - val_loss: 0.2779 - val_acc: 0.8878 - val_auroc: 0.8396 - val_auprc: 0.4779 - val_f1_m: 0.1109 - val_recall_m: 0.1110 - val_precision_m: 0.1159
# Epoch 131/150
# 14598/14598 [==============================] - 190s 13ms/step - loss: 0.2788 - acc: 0.8894 - auroc: 0.8399 - auprc: 0.4791 - f1_m: 0.1373 - recall_m: 0.1343 - precision_m: 0.1480 - val_loss: 0.2778 - val_acc: 0.8878 - val_auroc: 0.8400 - val_auprc: 0.4791 - val_f1_m: 0.1109 - val_recall_m: 0.1110 - val_precision_m: 0.1159
# Epoch 139/150
#  8060/14598 [===============>..............] - ETA: 1:22 - loss: 0.2738 - acc: 0.8901 - auroc: 0.8404 - auprc: 0.4805 - f1_m: 0.1452 - recall_m: 0.1438 - precision_m: 0.1536

# %%
# ROC in test set
ax = plt.figure(figsize=(5, 5))
plt.rcParams["font.size"] = 15
base_fpr = np.linspace(0, 1, 101)
tpr_list = []
auroc_list = []
for i in range(len(Y)):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(Y[i], y_pred_list[i])
    auroc_list.append(sklearn.metrics.roc_auc_score(Y[i], y_pred_list[i]))
    plt.plot(fpr, tpr, 'b', alpha=0.15)
    tpr = np.interp(base_fpr, fpr, tpr)
    tpr[0] = 0.0
    tpr_list.append(tpr)

print(len(tpr_list), len(tpr_list[0]), len(tpr_list[1]))
tpr_list = np.array(tpr_list)
mean_tpr = np.mean(np.array(tpr_list), axis=0)
tpr_std = tpr_list.std(axis=0)

tprs_upper = np.minimum(mean_tpr + 2 * tpr_std, 1)
tprs_lower = mean_tpr - 2 * tpr_std

plt.plot([0, 1], [0, 1], 'k--')
plt.plot(base_fpr, mean_tpr, 'b', label='Keras (area = {:.3f})'.format(np.mean(np.array(auroc_list))))
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.axes().set_aspect('equal', 'datalim')
with open('./output/03_mm10_evaluation_ATAC.2overlap.v8.oos-ROC.pickle','wb') as fid:
    pickle.dump(ax, fid)
#plt.savefig(figure_output_name+'.ROC.png')
# Out:
# 6 101 101
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# PRC in test set
ax = plt.figure(figsize=(5, 5))
plt.rcParams["font.size"] = 15
base_recall = np.linspace(0, 1, 101)
precision_list = []
auprc_list = []
for i in range(len(Y)):
    recall, precision, thresholds = sklearn.metrics.precision_recall_curve(Y[i], y_pred_list[i])
    auprc_list.append(sklearn.metrics.average_precision_score(Y[i], y_pred_list[i]))
    plt.plot(recall, precision, 'b', alpha=0.15)
    precision = np.interp(base_recall, recall, precision)
    precision[0] = 1.0
    precision_list.append(precision)

print(len(precision_list), len(precision_list[0]), len(precision_list[1]))
precision_list = np.array(precision_list)
mean_precision = np.mean(np.array(precision_list), axis=0)
precision_std = precision_list.std(axis=0)

precisions_upper = np.minimum(mean_precision + 2 * precision_std, 1)
precisions_lower = mean_precision - 2 * precision_std

plt.plot([0, 1], [1, 0], 'k--')
plt.plot(base_recall, mean_precision, 'b', label='Keras (area = {:.3f})'.format(np.mean(np.array(auprc_list))))
plt.fill_between(base_recall, precisions_lower, precisions_upper, color='grey', alpha=0.3)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('PRC curve')
plt.legend(loc='best')
plt.axes().set_aspect('equal', 'datalim')
with open('./output/03_mm10_evaluation_ATAC.2overlap.v8.oos-PRC.pickle','wb') as fid:
    pickle.dump(ax, fid)
#plt.savefig(figure_output_name+'.PRC.png')
# Out:
# 6 101 101
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
for i in range(len(samples)):
    print("validated tissue " + samples[i] + " auROC: " + str(auroc_list[i]))
print("overall auROC average " + str(np.mean(auroc_list)))
    
print("\n")

for i in range(len(samples)):
    print("validated tissue " + samples[i] + " auPRC: " + str(auprc_list[i]))
print("overall auPRC average " + str(np.mean(auprc_list)))
# Out:
# validated tissue forebrain auROC: 0.8621295464750786
# validated tissue heart auROC: 0.8535103264020985
# validated tissue hindbrain auROC: 0.8222781594536778
# validated tissue limb auROC: 0.8183592509684384
# validated tissue midbrain auROC: 0.8409403470544582
# validated tissue neural tube auROC: 0.8328880376855728
# overall auROC average 0.8383509446732207
#
#
# validated tissue forebrain auPRC: 0.5734218648014482
# validated tissue heart auPRC: 0.45594133253844665
# validated tissue hindbrain auPRC: 0.45004806069292863
# validated tissue limb auPRC: 0.4076842590575111
# validated tissue midbrain auPRC: 0.5379287360455264
# validated tissue neural tube auPRC: 0.3742306341751213
# overall auPRC average 0.46654248121849706

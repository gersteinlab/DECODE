# %% [markdown]
# Independent adenovirus-based assay experimental validation of 25 enhancer locations in H1 cells

# %%
#common python packages
import numpy as np
import pandas as pd
import string
import random
import os
import pickle
import argparse
import wget
import math
import matplotlib.pyplot as plt
from datetime import datetime

#biological packages
import pybedtools
from pybedtools import featurefuncs
import pyBigWig


#machine learning packages
import sklearn
from sklearn.utils import shuffle
from matplotlib import pyplot as plt
import pandas as pd
from scipy import stats

import tensorflow as tf
from tensorflow.python.framework import ops

import keras.backend as K
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Conv2D, MaxPooling2D, BatchNormalization, Flatten, GlobalAveragePooling2D, Multiply
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from keras import backend as K
from keras.engine.topology import Layer, InputSpec
from keras.utils import Sequence, plot_model
from keras.constraints import unit_norm
from keras import regularizers
from keras.callbacks import EarlyStopping, Callback, TensorBoard, ReduceLROnPlateau
import keras_metrics as km
from keras.models import load_model

from models.v10 import create_model
from models.custom_metrics import auroc, auprc, recall_m, precision_m, f1_m

import cv2

#notify the OS about GPU
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['KERAS_BACKEND'] = 'tensorflow'
# Out:
# Using TensorFlow backend.

# %%
exp_file_dir = "/gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/datasets/validation/Sutton/"
exp_file = exp_file_dir + "H1.tested_25_sites.hg38.mapped.bed"
H1_sites = pybedtools.BedTool(exp_file)
print(H1_sites.head(as_string=True))
print("Element Count: ", H1_sites.count())
interval_lengths = [len(i) for i in H1_sites]
print("Element Lengths: ", interval_lengths)
# Out:
# chr1	202888384	202889280
# chr1	32275061	32276172
# chr1	46340609	46341365
# chr2	24359711	24360769
# chr5	134176023	134177567
# chr5	1800942	1801850
# chr6	32153330	32154889
# chr6	52284352	52284853
# chr8	52713480	52714965
# chr9	127568166	127569926
#
# Element Count:  25
# Element Lengths:  [896, 1111, 756, 1058, 1544, 908, 1559, 501, 1485, 1760, 1283, 2139, 1509, 1527, 1410, 971, 666, 501, 1963, 1950, 889, 1432, 1815, 5936, 1087]

# %%
#expand annotations to 4kb
df = pd.read_csv(exp_file, sep="\t", usecols=[0,1,2], header=None)
new_start_list = []
new_stop_list = []
for index, row in df.iterrows():
    interval_len = int(row[2]) - int(row[1])
    new_start = int(row[1] - ((4000 - interval_len) / 2))
    new_start_list.append(new_start)
    new_stop_list.append(new_start + 4000)
df[1] = new_start_list
df[2] = new_stop_list
formatted_exp_name = exp_file.replace(".mapped.bed", ".4kb_expanded.bed")
df.to_csv(formatted_exp_name, sep="\t", header=None, index=None)
df

for index, row in df.iterrows():
    print(row[0] + ":" + str(row[1]) + "-" + str(row[2]))
# Out:
# chr1:202886832-202890832
# chr1:32273616-32277616
# chr1:46338987-46342987
# chr2:24358240-24362240
# chr5:134174795-134178795
# chr5:1799396-1803396
# chr6:32152109-32156109
# chr6:52282602-52286602
# chr8:52712222-52716222
# chr9:127567046-127571046
# chr9:129821783-129825783
# chr10:117373136-117377136
# chr10:69316788-69320788
# chr10:86519657-86523657
# chr11:10292198-10296198
# chr11:47765212-47769212
# chr12:56447116-56451116
# chr12:71752879-71756879
# chr14:34872370-34876370
# chr14:72924118-72928118
# chr16:4614357-4618357
# chr16:1473041-1477041
# chr19:55310618-55314618
# chr19:55482085-55486085
# chr21:33586608-33590608

# %%
H1_sites = pybedtools.BedTool(formatted_exp_name)

# %%
#IO the bigwig signals
bw_file_dir = "/gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/datasets/H1/"
track1_bw = bw_file_dir + "H1.DNase-seq.bigWig"
track2_bw = bw_file_dir + "H1.ChIP-seq.H3K27ac.bigWig"
track3_bw = bw_file_dir + "H1.ChIP-seq.H3K4me3.bigWig"
track4_bw = bw_file_dir + "H1.ChIP-seq.H3K9ac.bigWig"
track5_bw = bw_file_dir + "H1.ChIP-seq.H3K4me1.bigWig"
track_list = [track2_bw, track3_bw, track1_bw, track4_bw, track5_bw]
#track_list = [track1_bw, track2_bw, track3_bw, track4_bw, track5_bw]
track_files = [pyBigWig.open(i) for i in track_list]

def bigWigAverageOverBed(x, bigwig):
    return bigwig.stats(x.chrom, x.start, x.stop, nBins=400)

def get_signal(region, bigwig):
    return np.array([np.nan_to_num(np.array(bigWigAverageOverBed(x, bigwig), dtype=float)) for x in region])

# %%
signal_list = np.array([get_signal(H1_sites, i) for i in track_files])
print(signal_list[0][0][0], signal_list[0][1][0], signal_list[0][2][0], signal_list[0][3][0], signal_list[0][4][0])
print(signal_list[0][0][0], signal_list[1][0][0], signal_list[2][0][0], signal_list[3][0][0], signal_list[4][0][0])
signal_list.shape
# Out:
# 0.9158109784126282 1.1565900206565858 0.0 0.4976820111274719 0.3528680056333542
# 0.9158109784126282 1.7994680047035216 0.08291690051555634 1.128440022468567 1.9354969620704652
# (5, 25, 400)

# %%
signal_list_per_site = np.swapaxes(signal_list,0,1)
print(signal_list_per_site[0][0][0], signal_list_per_site[0][1][0], signal_list_per_site[0][2][0], signal_list_per_site[0][3][0], signal_list_per_site[0][4][0])
print(signal_list_per_site[0][0][0], signal_list_per_site[1][0][0], signal_list_per_site[2][0][0], signal_list_per_site[3][0][0], signal_list_per_site[4][0][0])
x_validation = np.expand_dims(signal_list_per_site, axis=4)
x_validation.shape
# Out:
# 0.9158109784126282 1.7994680047035216 0.08291690051555634 1.128440022468567 1.9354969620704652
# 0.9158109784126282 1.1565900206565858 0.0 0.4976820111274719 0.3528680056333542
# /gpfs/ysm/project/zc264/conda_envs/old_keras_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   after removing the cwd from sys.path.
# (25, 5, 400, 1)

# %%
window_size = 4000
model = create_model(width=int(window_size/10))
es = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
adam = Adam(lr=5e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=9e-5)
model.compile(loss='binary_crossentropy', optimizer=adam, 
              metrics = ['accuracy', auroc, auprc, f1_m, recall_m, precision_m])
model.load_weights('../dev/saved_models/DNase_hg38.v10.h5')
model.summary()
# Out:
# /gpfs/ysm/scratch60/gerstein/zc264/ChromVar/enhancer-prediction/encode/exp_validation/models/v9.py:53: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   model = Model(input=[input_size], output=[pred_output])
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 5, 400, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 5, 400, 128)  3968        input_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            1032        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          1152        dense_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 5, 400, 128)  0           conv2d_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 5, 400, 64)   245824      multiply_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 64)           0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            260         global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           320         dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 5, 400, 64)   0           conv2d_2[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 5, 400, 64)   122944      multiply_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 64)           0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            260         global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           320         dense_5[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 5, 400, 64)   0           conv2d_3[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 399, 128)  82048       multiply_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 128)          0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 8)            1032        global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          1152        dense_7[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 1, 399, 128)  0           conv2d_4[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 1, 390, 64)   81984       multiply_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 64)           0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 4)            260         global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           320         dense_9[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 1, 390, 64)   0           conv2d_5[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 381, 64)   41024       multiply_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 64)           0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 4)            260         global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 64)           320         dense_11[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 1, 381, 64)   0           conv2d_6[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 372, 64)   41024       multiply_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 64)           0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 4)            260         global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 64)           320         dense_13[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 1, 372, 64)   0           conv2d_7[0][0]
#                                                                  dense_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 1, 186, 64)   0           multiply_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 11904)        0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 256)          3047680     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1)            257         dropout_1[0][0]
# ==================================================================================================
# Total params: 3,674,021
# Trainable params: 3,674,021
# Non-trainable params: 0
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 5, 400, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 5, 400, 128)  3968        input_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            1032        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          1152        dense_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 5, 400, 128)  0           conv2d_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 5, 400, 64)   245824      multiply_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 64)           0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            260         global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           320         dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 5, 400, 64)   0           conv2d_2[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 5, 400, 64)   122944      multiply_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 64)           0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            260         global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           320         dense_5[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 5, 400, 64)   0           conv2d_3[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 399, 128)  82048       multiply_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 128)          0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 8)            1032        global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          1152        dense_7[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 1, 399, 128)  0           conv2d_4[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 1, 390, 64)   81984       multiply_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 64)           0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 4)            260         global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           320         dense_9[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 1, 390, 64)   0           conv2d_5[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 381, 64)   41024       multiply_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 64)           0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 4)            260         global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 64)           320         dense_11[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 1, 381, 64)   0           conv2d_6[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 372, 64)   41024       multiply_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 64)           0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 4)            260         global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 64)           320         dense_13[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 1, 372, 64)   0           conv2d_7[0][0]
#                                                                  dense_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 1, 186, 64)   0           multiply_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 11904)        0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 256)          3047680     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1)            257         dropout_1[0][0]
# ==================================================================================================
# Total params: 3,674,021
# Trainable params: 3,674,021
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
prediction_results = model.predict(x_validation)

# %%
np.savetxt("h1.tested_25_sites.prediction.tsv", prediction_results, delimiter="\t")
prediction_results_filtered = [i for idx, i in enumerate(prediction_results) if idx not in [10, 19, 23]]
for i in prediction_results_filtered:
    print(i[0])
# Out:
# 0.99571
# 0.85347396
# 0.9683355
# 0.9912822
# 0.8904022
# 0.98629886
# 0.99785715
# 0.32488388
# 0.85951424
# 0.8297518
# 0.9827261
# 0.982092
# 0.5402102
# 0.9919321
# 0.6446337
# 0.9808822
# 0.2177925
# 0.12318535
# 0.9881676
# 0.9963154
# 6.922745e-05
# 0.59471184

# %%
def normalize(x):
    """Utility function to normalize a tensor by its L2 norm"""
    return (x + 1e-10) / (K.sqrt(K.mean(K.square(x))) + 1e-10)

def cam_pred_1d(model, x_validation):
    """GradCAM method for visualizing input saliency."""
    layer_name = "conv2d_7"

    y_c = model.output
    conv_output = model.get_layer(layer_name).output
    grads = K.gradients(y_c, conv_output)[0]

    # Normalize if necessary
    grads = normalize(grads)
    gradient_function = K.function([model.input], [conv_output, grads])

    output, grads_val = gradient_function([x_validation])
    output, grads_val = output[0, :], grads_val[0, :, :, :]

    weights = np.mean(grads_val, axis=(0, 1))
    cam = np.dot(output, weights)
    cam = cv2.resize(cam, (200, 1), cv2.INTER_LINEAR)
    cam = np.maximum(cam, 0)
    #cam = cam / cam.max()
    return cam

def cam_pred_5d(model, x_validation):
    """GradCAM method for visualizing input saliency."""
    layer_name = "conv2d_3"

    y_c = model.output
    conv_output = model.get_layer(layer_name).output
    grads = K.gradients(y_c, conv_output)[0]

    # Normalize if necessary
    grads = normalize(grads)
    gradient_function = K.function([model.input], [conv_output, grads])

    output, grads_val = gradient_function([x_validation])
    output, grads_val = output[0, :], grads_val[0, :, :, :]

    weights = np.mean(grads_val, axis=(0, 1))
    cam = np.dot(output, weights)
    cam = cv2.resize(cam, (200, 5), cv2.INTER_LINEAR)
#     print(cam.shape)
    cam = np.maximum(cam, 0)
#     cam = cam / cam.max()
    return cam

# %%
seq_names = ["H3K27ac", "H3K4me3", "DNase", "H3K9ac", "H3K4me1"]
for idx, item in enumerate(x_validation):
    plt.title("Enhancer Localization\nProbability: " + str(prediction_results[idx]))
    gradcam_1d = cam_pred_1d(model, np.expand_dims(x_validation[idx], axis=0))[0]
    #norm_gradcam_1d = gradcam_1d / np.max(gradcam_1d)
    plt.plot(gradcam_1d)
    plt.xticks([])
    plt.show();

    cam_5d = cam_pred_5d(model, np.expand_dims(x_validation[idx], axis=0))
    for i in [0,1,2,3,4]:
        plt.plot(cam_5d[i,], label=track_list[i].replace(".bigWig", "").replace("H1.", "").replace(bw_file_dir, ""))
    plt.legend()
    plt.xticks([])
    plt.show();
